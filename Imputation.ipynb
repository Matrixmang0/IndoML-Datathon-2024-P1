# %% [markdown]
# ## Importing Libraries and Modules
#
# In this cell, we import the necessary libraries and modules required for the task:
#
# - **pandas**: For data manipulation and analysis.
# - **transformers**: Includes the `T5Tokenizer` and `T5ForConditionalGeneration` classes for tokenizing text and generating predictions using the T5 model.
# - **datasets**: Provides the `Dataset` and `DatasetDict` classes for handling datasets.
# - **numpy**: For numerical operations.
#
# These libraries and modules will be used for data processing, model training, and evaluation.

# %%
import pandas as pd
from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments, TrainerCallback
from datasets import Dataset, DatasetDict
import numpy as np

# %% [markdown]
# ## Reading Data from JSONL Files
#
# In this cell, we define a function `read_jsonl` to read data from JSON Lines (JSONL) files into pandas DataFrames. We then use this function to read the following datasets:
#
# - **Training Data**: `attrebute_train.data` and `attrebute_train.solution`, with the first 1000 rows.
# - **Testing Data**: `attrebute_test.data` and `attrebute_test.solution`, with the first 200 rows.
# - **Validation Data**: `attrebute_val.data` and `attrebute_val.solution`, with the first 200 rows.
#
# The commented-out lines are for reading the entire datasets if needed. This setup allows us to work with a subset of the data for initial experimentation and testing.

# %%
train_data = pd.read_json('./input_data/attribute_train.data', lines=True)
train_solution = pd.read_json('./input_data/attribute_train.solution', lines=True)
test_data = pd.read_json('./input_data/attribute_test.data', lines=True)
val_data = pd.read_json('./input_data/attribute_val.data', lines=True)
val_solution = pd.read_json('./input_data/attribute_val.solution', lines=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443499 entries, 0 to 443498
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   indoml_id             443499 non-null  int64
#  1   title                 443499 non-null  object
#  2   store                 443499 non-null  object
#  3   details_Manufacturer  437775 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95035 entries, 0 to 95034
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   indoml_id             95035 non-null  int64
#  1   title                 95035 non-null  object
#  2   store                 95035 non-null  object
#  3   details_Manufacturer  93802 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.9+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95036 entries, 0 to 95035
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   indoml_id             95036 non-null  int64
#  1   title                 95036 non-null  object
#  2   store                 95036 non-null  object
#  3   details_Manufacturer  93816 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.9+ MB

# %%
total_data = pd.concat([train_data, val_data, test_data], axis=0)
total_data = total_data.reset_index(drop=True)
total_data
# Out:
#         indoml_id                                              title  \
# 0               0  Enclume Angled Pot Hook, Set of 6, Use with Po...
# 1               1       Schutt Vengeance DCT Hybrid Youth Football H
# 2               2         Easton 2014 MAKO SL14MK9 Baseball Bat (-9)
# 3               3    Bilstein B46-0929 Heavy-Duty Gas Shock Absorber
# 4               4  Apple Red Cardstock - 8.5 x 11 inch - 65Lb Cov...
# ...           ...                                                ...
# 633565      95031              Discraft Avenger SS Elite Z Golf Disc
# 633566      95032   ProLume Prolumeme F30T12DL 9236 F30 T12 Daylight
# 633567      95033   Nearly Natural 4842-S3 Colorful Cactus, Set of 3
# 633568      95034  Gorilla Automotive 90038 Acorn Bulge Open End ...
# 633569      95035  LUXPaper A2 Contour Flap Invitation Envelopes ...
#
#                    store         details_Manufacturer
# 0                Enclume                      Enclume
# 1                 Schutt                       Schutt
# 2                 Easton          Easton Sports, Inc.
# 3               Bilstein                     Bilstein
# 4       Clear Path Paper             Clear Path Paper
# ...                  ...                          ...
# 633565          Discraft                     Discraft
# 633566           Prolume  Halco Lighting Technologies
# 633567    Nearly Natural               Nearly Natural
# 633568           GORILLA           Gorilla Automotive
# 633569          LUXPaper                     LUXPaper
#
# [633570 rows x 4 columns]

# %%
nonan_data = total_data.dropna()
nonan_data = nonan_data.reset_index(drop=True)
nan_data = total_data[total_data.isna().any(axis=1)]
nan_data = nan_data.reset_index(drop=True)

# %%
print(len(nonan_data))
print(len(nan_data))
print(len(nonan_data)+len(nan_data))
# Out:
# 625393
# 8177
# 633570

# %%
nonan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625393 entries, 0 to 625392
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   indoml_id             625393 non-null  int64
#  1   title                 625393 non-null  object
#  2   store                 625393 non-null  object
#  3   details_Manufacturer  625393 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 19.1+ MB

# %%
nan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8177 entries, 0 to 8176
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   indoml_id             8177 non-null   int64
#  1   title                 8177 non-null   object
#  2   store                 8177 non-null   object
#  3   details_Manufacturer  0 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 255.7+ KB

# %%
tstdata = nan_data.drop(['details_Manufacturer'], axis=1)

# %%
tstdata
# Out:
#       indoml_id                                              title  \
# 0            27  Munchkin Dora the Explorer Click Lock Insulate...
# 1            78  Carter's Forest Friends Fitted Sheet, Tan/Choc...
# 2           139  VP-Zoom Sportscope - 4x9 Magnification - Manuf...
# 3           192  Seventh Generation Baby Free & Clear Overnight...
# 4           303  Operandi 12 Pack Melon Cradle Supports Durable...
# ...         ...                                                ...
# 8172      94854  BIBS Baby Pacifier | BPA-Free Natural Rubber |...
# 8173      94893  Jackson Pro Series Soloist SL2P MAH Electric G...
# 8174      94915  Wallmonkeys WM249565 Baby Two-Toed Sloth 4 Mon...
# 8175      94917                     Dr. Brown's Training Cup, Blue
# 8176      95003  Dr. Brown's Original Glass Bottle, 8 Ounce, 3-...
#
#                    store
# 0               Munchkin
# 1               Carter's
# 2                 XGATML
# 3     Seventh Generation
# 4               Aeiniwer
# ...                  ...
# 8172                Bibs
# 8173             Jackson
# 8174         Wallmonkeys
# 8175         Dr. Brown's
# 8176         Dr. Brown's
#
# [8177 rows x 3 columns]

# %%
soln = pd.DataFrame(nonan_data['details_Manufacturer'].copy())
data = nonan_data.drop(['details_Manufacturer', 'indoml_id'], axis=1)

# %%
from sklearn.model_selection import train_test_split

trdata, valdata, trsoln, valsoln = train_test_split(data, soln, test_size=0.02)

# %%
trdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 612885 entries, 549316 to 156852
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   612885 non-null  object
#  1   store   612885 non-null  object
# dtypes: object(2)
# memory usage: 14.0+ MB

# %%
len(trdata)
# Out:
# 612885

# %%
valdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12508 entries, 299645 to 218401
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   12508 non-null  object
#  1   store   12508 non-null  object
# dtypes: object(2)
# memory usage: 293.2+ KB

# %%
len(valdata)
# Out:
# 12508

# %%
trsoln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 612885 entries, 549316 to 156852
# Data columns (total 1 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   details_Manufacturer  612885 non-null  object
# dtypes: object(1)
# memory usage: 9.4+ MB

# %%
len(trsoln)
# Out:
# 612885

# %%
valsoln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12508 entries, 299645 to 218401
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   details_Manufacturer  12508 non-null  object
# dtypes: object(1)
# memory usage: 195.4+ KB

# %%
len(valsoln)
# Out:
# 12508

# %%
trdata.iloc[0]
# Out:
# title    BOSCH BP1397 QuietCast Premium Semi-Metallic D...
# store                                                BOSCH
# Name: 549316, dtype: object

# %% [markdown]
# ## Data Preprocessing and Formatting
#
# In this cell, we define a function `preprocess_data` to prepare the data for model training. This function merges the product description data with the corresponding attribute labels, then formats the data into `input_text` and `target_text` pairs:
#
# - **`input_text`**: Constructed by combining the product title, store, and manufacturer details.
# - **`target_text`**: Constructed by specifying the attribute-value pairs for brand and categories.
#
# ### Data Processing
#
# We apply the `preprocess_data` function to the training, testing, and validation datasets to generate the `input_text` and `target_text`.
#
# Finally, the processed data is converted into the Hugging Face Dataset format using `Dataset.from_pandas` for further model training and evaluation.

# %%
def combine_infos(row):
    text = 'The title of the product is ' + row['title'] + '. This product was bought at the store ' + row['store'] + '.'
    return text

def preprocess_data(data):
    print(data.isnull().sum())
    df = pd.DataFrame()
    df['input_text'] = data.apply(combine_infos, axis=1)

    return df

def preprocess_target(solution):
    print(solution.isnull().sum())
    df = pd.DataFrame()
    df['target_text'] = solution.apply(lambda row: f"details_Manufacturer: {row['details_Manufacturer']}", axis=1)

    return df

trftrs_processed = preprocess_data(trdata)
trtgt_processed = preprocess_target(trsoln)
valftrs_processed = preprocess_data(valdata)
valtgt_processed = preprocess_target(valsoln)
tstftrs_processed = preprocess_data(tstdata)
# Out:
# title    0
# store    0
# dtype: int64
# details_Manufacturer    0
# dtype: int64
# title    0
# store    0
# dtype: int64
# details_Manufacturer    0
# dtype: int64
# indoml_id    0
# title        0
# store        0
# dtype: int64

# %%
trftrs_processed
# Out:
#                                                input_text
# 549316  The title of the product is BOSCH BP1397 Quiet...
# 512557  The title of the product is Power Stop K1797-3...
# 258568  The title of the product is Lexmark 10N0227 In...
# 289041  The title of the product is Skinit Decal Audio...
# 548613  The title of the product is Rainlemon Thanksgi...
# ...                                                   ...
# 593474  The title of the product is Shimano STC Spin, ...
# 572174  The title of the product is Shark Navigator Up...
# 245751  The title of the product is Fisch Brad Point D...
# 434984  The title of the product is Lamy Logo M + 204 ...
# 156852  The title of the product is CURT Class 3 Trail...
#
# [612885 rows x 1 columns]

# %%
trftrs_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 612885 entries, 549316 to 156852
# Data columns (total 1 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   input_text  612885 non-null  object
# dtypes: object(1)
# memory usage: 9.4+ MB

# %%
trtgt_processed
# Out:
#                                       target_text
# 549316                details_Manufacturer: Bosch
# 512557           details_Manufacturer: Power Stop
# 258568  details_Manufacturer: LEXMARK INT'L, INC.
# 289041               details_Manufacturer: Skinit
# 548613            details_Manufacturer: Rainlemon
# ...                                           ...
# 593474              details_Manufacturer: Shimano
# 572174           details_Manufacturer: SharkNinja
# 245751       details_Manufacturer: Affinity Tools
# 434984            details_Manufacturer: Lamy GmbH
# 156852   details_Manufacturer: Curt Manufacturing
#
# [612885 rows x 1 columns]

# %%
trtgt_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 612885 entries, 549316 to 156852
# Data columns (total 1 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   target_text  612885 non-null  object
# dtypes: object(1)
# memory usage: 9.4+ MB

# %%
# Convert to Hugging Face Dataset format
train_dataset = Dataset.from_pandas(pd.concat([trftrs_processed, trtgt_processed], axis=1))
val_dataset = Dataset.from_pandas(pd.concat([valftrs_processed, valtgt_processed], axis=1))
test_dataset = Dataset.from_pandas(tstftrs_processed)

# %%
train_dataset[:5]
# Out:
# {'input_text': ['The title of the product is BOSCH BP1397 QuietCast Premium Semi-Metallic Disc Brake Pad Set - Compatible With Select Hyundai Elantra; Kia Forte, Forte Koup, Forte5, Soul; FRONT. This product was bought at the store BOSCH.',
#   'The title of the product is Power Stop K1797-36 Front and Rear Z36 Truck & Tow Brake Kit, Carbon Fiber Ceramic Brake Pads and Drilled/Slotted Brake Rotors. This product was bought at the store Power Stop.',
#   'The title of the product is Lexmark 10N0227 Ink Cartridge (27), Tri-Color - in Retail Packaging. This product was bought at the store Lexmark.',
#   'The title of the product is Skinit Decal Audio Skin Compatible with Apple AirPods with Lightning Charging Case - Officially Licensed NFL Kansas City Chiefs Red Performance Series Design. This product was bought at the store Skinit.',
#   'The title of the product is Rainlemon Thanksgiving Day Happy Fall Halloween Harvest Pumpkin Burlap Banner Garland Bunting Home Party Decoration. This product was bought at the store Rainlemon.'],
#  'target_text': ['details_Manufacturer: Bosch',
#   'details_Manufacturer: Power Stop',
#   "details_Manufacturer: LEXMARK INT'L, INC.",
#   'details_Manufacturer: Skinit',
#   'details_Manufacturer: Rainlemon'],
#  '__index_level_0__': [549316, 512557, 258568, 289041, 548613]}

# %% [markdown]
# ## Creating Dataset Dictionary
#
# In this cell, we create a `DatasetDict` to organize the processed datasets for training, testing, and validation. The `DatasetDict` is a convenient way to manage multiple datasets in Hugging Face's `datasets` library.
#
# - **`train`**: Contains the training dataset (`train_dataset`).
# - **`test`**: Contains the test dataset (`test_dataset`).
# - **`validation`**: Contains the validation dataset (`val_dataset`).
#
# The `DatasetDict` will be used for training and evaluating the model, allowing for easy access to different subsets of data.

# %%
dataset_dict = DatasetDict({
    'train': train_dataset,
    'validation': val_dataset
})

# %%
dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'target_text', '__index_level_0__'],
#         num_rows: 612885
#     })
#     validation: Dataset({
#         features: ['input_text', 'target_text', '__index_level_0__'],
#         num_rows: 12508
#     })
# })

# %% [markdown]
# ## Loading the T5 Model and Tokenizer
#
# In this cell, we load the T5 model and tokenizer from the Hugging Face `transformers` library:
#
# - **`T5Tokenizer`**: Tokenizer for converting text into tokens and vice versa, using the `t5-small` pre-trained model.
# - **`T5ForConditionalGeneration`**: T5 model for sequence-to-sequence tasks, also using the `t5-small` pre-trained model.
#
# These components will be used for encoding the input text, generating predictions, and decoding the output text.

# %%
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-small")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-small")

# %% [markdown]
# ## Tokenizing the Dataset
#
# In this cell, we define the `preprocess_function` to tokenize the `input_text` and `target_text` using the T5 tokenizer:
#
# - **`inputs`**: Tokenized input texts with a maximum length of 352 tokens, padded and truncated as necessary.
# - **`targets`**: Tokenized target texts with a maximum length of 128 tokens, padded and truncated as necessary.
# - **`model_inputs`**: Contains the tokenized inputs and labels (target texts) for model training.
#
# The `preprocess_function` is applied to the entire dataset using the `map` method with `batched=True`, ensuring efficient processing of the data in batches.
#
# The result, `tokenized_datasets`, is a `DatasetDict` containing the tokenized versions of the train, test, and validation datasets, ready for model training.

# %%
def preprocess_trval(examples):
    inputs = examples['input_text']
    targets = examples['target_text']
    
    model_inputs = tokenizer(inputs, max_length=128, padding='max_length', truncation=True)
    labels = tokenizer(targets, max_length=128, padding='max_length', truncation=True)
    model_inputs['labels'] = labels['input_ids']

    return model_inputs

tokenized_datasets = dataset_dict.map(preprocess_trval, batched=True)

# %%
tokenized_datasets

# %%
tokenized_datasets.save_to_disk('./impute_Input_tokens/')

# %%
from datasets import load_from_disk

tokenized_datasets = load_from_disk('./impute_Input_tokens/')

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'target_text', '__index_level_0__', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 612885
#     })
#     validation: Dataset({
#         features: ['input_text', 'target_text', '__index_level_0__', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 12508
#     })
# })

# %% [markdown]
# ## Configuring Training Arguments
#
# In this cell, we set up the `TrainingArguments` for training the T5 model using the Hugging Face `Trainer`:
#
# - **`output_dir`**: Directory to save the model checkpoints and results.
# - **`evaluation_strategy`**: Strategy for evaluation, set to `'epoch'`, meaning evaluation will occur at the end of each epoch.
# - **`learning_rate`**: Learning rate for optimization, set to `2e-5`.
# - **`per_device_train_batch_size`**: Batch size for training, set to `16`.
# - **`per_device_eval_batch_size`**: Batch size for evaluation, set to `16`.
# - **`num_train_epochs`**: Number of training epochs, set to `2`.
# - **`weight_decay`**: Weight decay for regularization, set to `0.01`.
# - **`save_total_limit`**: Limit on the number of checkpoints to keep, set to `3`.
# - **`logging_dir`**: Directory for logging information.
# - **`logging_steps`**: Frequency of logging, set to every 20 steps.
# - **`report_to`**: Reporting options, set to `'none'` to disable reporting.
#
# These arguments control various aspects of the training process and ensure efficient training and logging.

# %%
training_args = TrainingArguments(
    output_dir='./impute_fT5small',
    eval_strategy='epoch',
    eval_accumulation_steps=32,
    save_strategy='steps',
    save_total_limit=1,
    learning_rate=2e-3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    fp16=True,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_first_step=True,
    logging_steps=20,
    report_to='tensorboard'
)

# %% [markdown]
# ## Defining a Custom Callback for Logging
#
# In this cell, we define a custom callback class `CustomCallback` that extends `TrainerCallback` from the Hugging Face `transformers` library:
#
# - **`on_log` Method**: This method is triggered during the training process whenever logging occurs. It prints:
#   - The current training step (`state.global_step`).
#   - Each key-value pair in the `logs` dictionary.
#
# This custom callback allows for detailed logging of training progress and metrics directly to the console, providing real-time feedback during the training process.

# %%
class CustomCallback(TrainerCallback):
    def on_log(self, args, state, control, logs=None, **kwargs):
        if logs is not None:
            print(f"Step: {state.global_step}")
            for key, value in logs.items():
                print(f"{key}: {value}")
            print("\n")

# %% [markdown]
# ## Training the Model
#
# In this cell, we initialize and run the `Trainer` for training the T5 model:
#
# - **`model`**: The T5 model to be trained.
# - **`args`**: The `TrainingArguments` specified in the previous cell.
# - **`train_dataset`**: The tokenized training dataset.
# - **`eval_dataset`**: The tokenized validation dataset.
# - **`callbacks`**: The list of callbacks to use during training, including the custom `CustomCallback` defined earlier.
#
# After setting up the `Trainer`, we call `trainer.train()` to start the training process. The custom callback will print detailed logging information during training.

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import torch

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['validation'],
    callbacks=[CustomCallback()]
)

torch.cuda.empty_cache()
trainer.train()

# %% [markdown]
# ## Saving the Fine-Tuned Imputer Model
#
# In this cell, we save the fine-tuned T5 model and tokenizer to a specified directory:
#
# - **`model.save_pretrained('./finetuned_fT5_impute')`**: Saves the trained T5 model to the directory `./fine_tuned_t5`. This allows you to load the model later without retraining.
#
# - **`tokenizer.save_pretrained('./finetuned_fT5_impute')`**: Saves the tokenizer associated with the T5 model to the same directory. This ensures that you can use the same tokenizer for encoding and decoding text during inference.
#
# Saving both the model and tokenizer ensures that you can resume work or deploy the model in the future with consistent results.

# %%
model.save_pretrained('./finetuned_fT5_impute')
tokenizer.save_pretrained('./finetuned_fT5_impute')

# %% [markdown]
# ## Loading the Fine-Tuned Model and Tokenizer
#
# In this cell, we load the fine-tuned T5 model and tokenizer from the specified directory and set up the environment for evaluation:
#
# - **`device`**: Determines whether to use a GPU (`cuda`) or CPU for computation based on availability.
#
# - **`model`**: Loads the fine-tuned T5 model and moves it to the appropriate device (`cuda` or `cpu`).
#
# - **`tokenizer`**: Loads the tokenizer associated with the fine-tuned T5 model.
#
# The model is set to evaluation mode with `model.eval()`, preparing it for generating predictions.
#
# ### Functions
#
# - **`generate_text(inputs)`**: Takes a batch of input texts, tokenizes them, and generates predictions using the fine-tuned model. It returns the generated texts after decoding them from token IDs.
#
# - **`extract_details(text)`**: Extracts attribute details from the generated or target text using regular expressions. It returns the details for brand and categories, defaulting to `'na'` if not found.
#
# - **`clean_repeated_patterns(text)`**: Cleans the generated text by removing redundant patterns, specifically handling the `L4_category`.
#
# These functions will be used for generating predictions and extracting and cleaning the details from the results.

# %%
import re
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import T5ForConditionalGeneration, T5Tokenizer
import torch
from tqdm import tqdm

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = T5ForConditionalGeneration.from_pretrained('./finetuned_fT5_impute').to(device)
tokenizer = T5Tokenizer.from_pretrained('./finetuned_fT5_impute')

model.eval()

test_data = test_dataset['input_text']

def generate_text(inputs):
    inputs = tokenizer.batch_encode_plus(inputs, return_tensors="pt", padding=True, truncation=True, max_length=352)
    inputs = {key: value.to(device) for key, value in inputs.items()}

    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=128)

    generated_texts = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return generated_texts

def extract_details(text):
    pattern = r'details_Manufacturer:\s*(.+)'
    match = re.search(pattern, text)
    if match:
        return match.group(1).strip()
    return 'na'

def clean_repeated_patterns(text):
    cleaned_data = text.split(' L4_category')[0]
    return cleaned_data

# %%
test_data
# Out:
# ['The title of the product is Munchkin Dora the Explorer Click Lock Insulated Straw Cups BPA Free 9oz 266ml - 3pk. This product was bought at the store Munchkin.',
#  "The title of the product is Carter's Forest Friends Fitted Sheet, Tan/Choc, 28 X 52 (Discontinued by Manufacturer). This product was bought at the store Carter's.",
#  'The title of the product is VP-Zoom Sportscope - 4x9 Magnification - Manufactured by Mickelson Group - Patent Protected. This product was bought at the store XGATML.',
#  'The title of the product is Seventh Generation Baby Free & Clear Overnight Diapers, Size 6 (68 Count). This product was bought at the store Seventh Generation.',
#  'The title of the product is Operandi 12 Pack Melon Cradle Supports Durable Plastic with 3 Sturdy Legs 21.5 X 20 cm Includes 5 Metres of Soft Garden Plant Ties. This product was bought at the store Aeiniwer.',
#  'The title of the product is Halo Pink Dot Butterfly Sleepsack Wearable Baby Blanket, Micro-Fleece, Small. This product was bought at the store HALO.',
#  'The title of the product is Seymour Duncan Alnico II Pro Humbucker Pickup - Black Neck. This product was bought at the store Seymour Duncan.',
#  'The title of the product is Odyssey FRERGOBL BL Pioneer Ddj-Ergo-V Road Case. This product was bought at the store ODYSSEY.',
#  'The title of the product is SwaddleDesigns Baby Lovie, Small Security Blanket, Jewel Tone Puff Circles with Satin Trim, Blue. This product was bought at the store SwaddleDesigns.',
#  'The title of the product is Huggies Soft Skin Baby Wipes, Shea Butter, Pop-Up Tub, 64 Count. This product was bought at the store HUGGIES.',
#  'The title of the product is The Kids Room by Stupell You Re My Sunshine Rainbow Colors Typography Rectangle Wall Plaque, 11 x 0.5 x 15, Proudly Made in USA. This product was bought at the store Stupell Industries.',
#  'The title of the product is Evenflo EveryFit 4-in-1 Convertible Car Seat. This product was bought at the store Evenflo.',
#  'The title of the product is Chauvet DJ 4BAR Flex Q RGBA LED Wash System with 4 Lights and Carry Bag. This product was bought at the store CHAUVET DJ.',
#  'The title of the product is decalmile 6 Nautical Hot Air Balloons Wall Decals Stars Cloud Star Wall Stickers Baby Nursery Kids Bedroom Wall Decor(Size: 10/6 H). This product was bought at the store decalmile.',
#  'The title of the product is aden + anais Single Swaddle Baby Blanket, 100% Cotton Muslin, Large 47 X 47 inch, Wink. This product was bought at the store aden + anais.',
#  'The title of the product is Diapers Size 3, 168 Count and Size 4, 150 Count- Pampers Swaddlers Disposable Baby Diapers, One Month Supply with $20 Gift Card. This product was bought at the store Pampers.',
#  'The title of the product is HALO Sleepsack Cotton Wearable Blanket, White, XL. This product was bought at the store HALO.',
#  'The title of the product is AC/DC Adapter for Sony Bravia KDL-40R510C KDL-48W600B Smart LED HDTV Power Supply Cord Cable PS Charger Input: 100-240 VAC 50/60Hz Worldwide Voltage Use Mains PSU. This product was bought at the store EPtech.',
#  'The title of the product is Nuby Chewy Chums All Silicone Soothing Teether, Helicopter- 3M+. This product was bought at the store Nuby.',
#  'The title of the product is Jackson SLX Soloist X Series Electric Guitar Slime Green. This product was bought at the store Jackson.',
#  'The title of the product is Hohner Bluesband Blues Harmonica Key of C. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Pampers Swaddlers, Size 2-3, 30-Count. This product was bought at the store Pampers.',
#  'The title of the product is Jackson X Series Soloist SLXM DX 6-String Electric Guitar with Maple Fingerboard and Neck-Through-Body (Right-Handed, Snow White). This product was bought at the store Jackson.',
#  'The title of the product is U.S. Army Logo on Camo Novelty Guitar Picks Medium Gauge - Set of 6. This product was bought at the store GRAPHICS & MORE.',
#  'The title of the product is Oscar Schmidt Concert Active EQ, Acoustic Electric Ukulele, OU2E w/Hard Case,Tuner,Strings & PC. This product was bought at the store Oscar Schmidt.',
#  'The title of the product is Thirsties Duo Fab Fitted Snap Cloth Diapers, Ocean Blue, Size One (6-18 lbs). This product was bought at the store Thirsties.',
#  'The title of the product is Lambs & Ivy Dena Happi Tree, Blanket. This product was bought at the store Lambs & Ivy.',
#  "The title of the product is Gibson Les Paul 50's Tribute Guitar Wine Red Vintage Gloss. This product was bought at the store Gibson.",
#  'The title of the product is K-Musculo SUPOW Medical Bandage Rescue Scissors, 3pack EDC Tactical Multi Function Rescue Bandage Scissor with Saw Tooth for Emergency First Aid Shears Outdoor. This product was bought at the store XGATML.',
#  'The title of the product is SwaddleDesigns Marquisette Swaddling Blanket, Premium Cotton Muslin, Yellow Jewel Tone Little Chickies. This product was bought at the store SwaddleDesigns.',
#  'The title of the product is Fender Classic Player Strat HH. This product was bought at the store Fender.',
#  'The title of the product is Baby Jogger City Mini GT2 Stroller, Barre Collection. This product was bought at the store Baby Jogger.',
#  'The title of the product is Kala Brand Music Co. Makala Dolphin, 4-String Ukulele, Green Apple Burst, Soprano (MK-SD/GRNBURST). This product was bought at the store Kala.',
#  "The title of the product is Fender Limited Edition Made in Japan Traditional '60s Jazzmaster Electric Guitar (Blue Flower). This product was bought at the store Fender.",
#  'The title of the product is Sweet Jojo Designs Black and White Triangle Tree Fabric Memory Memo Photo Bulletin Board for Bear Mountain Watercolor Collection by. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Dunlop Primetone Standard 1.3mm Sculpted Plectra (Grip) - 12 Pack. This product was bought at the store JIM DUNLOP.',
#  'The title of the product is Seymour Duncan SJBJ-1b JB Jr. Humb Bridge Pickup, Parchment. This product was bought at the store Seymour Duncan.',
#  'The title of the product is decalmile Princess Castle Wall Stickers Snow Unicorn Snowflake Wall Decals Girls Bedroom Baby Nursery Wall Decor. This product was bought at the store decalmile.',
#  'The title of the product is Seymour Duncan SJM-1n Vintage Pickup for Jazzmaster Neck Position. This product was bought at the store Seymour Duncan.',
#  'The title of the product is The First Years Insulated Straw Cup - Finding Nemo - 9 oz. This product was bought at the store The First Years.',
#  'The title of the product is Seymour Duncan STHR-1B Hot Rails Bridge Pickup for Tele. This product was bought at the store Seymour Duncan.',
#  "The title of the product is Graco Swing 'N Bounce 3-in-1 Infant Swing in Graham. This product was bought at the store Graco.",
#  'The title of the product is Pirastro Evah Pirazzi 4/4 Violin E String Medium Steel Ball-End. This product was bought at the store Pirastro.',
#  'The title of the product is HALO SleepSack 100% Cotton Wearable Blanket, Gray, X-Large (Discontinued by Manufacturer). This product was bought at the store HALO.',
#  'The title of the product is ESP EC256 LTD Eclipse Electric Guitar (Aged Goldtop). This product was bought at the store ESP.',
#  'The title of the product is The Metropolitan Museum of Art Oven Mitts Flame Retardant Mitts Heat Resistant and Flexibility of Cotton to 425 F by M&G COLLECTION. This product was bought at the store Aeiniwer.',
#  'The title of the product is Evenflo SureRide DLX Convertible Car Seat, Bishop. This product was bought at the store Evenflo.',
#  'The title of the product is VEGFEST AEscod Black & Cream Mini Wreath Or Candle Ring Country Primitive Floral Dcor Perfect Candle Ring for 4 Pillars (Wreath is 8). This product was bought at the store XGATML.',
#  'The title of the product is The Kids Room by Stupell Multi-Sport Blue and Red Striped Growth Chart, 7 x 0.5 x 39, Proudly Made in USA. This product was bought at the store Stupell Industries.',
#  'The title of the product is Pampers Extra Protection Nighttime Diapers Super Pack Size 3 96 Count. This product was bought at the store Pampers.',
#  'The title of the product is aden by aden + anais Swaddleplus Boys-n-Toys 4-Pack. This product was bought at the store aden + anais.',
#  'The title of the product is Ibanez GSR200BWNF 4-String Electric Bass Walunt Flat Finish with Gig Bag. This product was bought at the store Ibanez.',
#  'The title of the product is PRS SE Custom 24 Left-handed Electric Guitar - Faded Blue Burst. This product was bought at the store PRS.',
#  'The title of the product is inktastic Future Rugby Player Baby Bib. This product was bought at the store inktastic.',
#  'The title of the product is THE HONEST COMPANY Pandas Size 1 Diapers, 35 CT. This product was bought at the store The Honest Company.',
#  'The title of the product is Halo Sleepsack Cotton Wearable Blanket, Giraffe Elephant Print, Medium. This product was bought at the store HALO.',
#  'The title of the product is Sheer Organza Ribbon 25 Yard Roll 1/4 White. This product was bought at the store K-MusculoAABBCC.',
#  'The title of the product is Sweet Jojo Designs Changing Pad Cover - Ladybug Parade. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is PreSonus Studio 24c USB-C Audio Interface 2-in/2-out USB-C Audio Interface with 2 Xmax-L Preamps with Headphone and Cables. This product was bought at the store PreSonus.',
#  'The title of the product is Britax USA Advocate ClickTight Convertible Car Seat, Tahoe. This product was bought at the store BRITAX.',
#  'The title of the product is DECOWALL DWL-1811N Coral Reef Fish Kids Wall Stickers Wall Decals Peel and Stick Removable Wall Stickers for Kids Nursery Bedroom Living Room dcor. This product was bought at the store DECOWALL.',
#  'The title of the product is Pampers Swaddlers Disposable Baby Diapers Size 6, 2 Month Supply (2 x 108 Count) with Sensitive Water Based Baby Wipes, 12X Pop-Top Packs (864 Count). This product was bought at the store Pampers.',
#  'The title of the product is Sweet Jojo Designs Grey Woodland Deer Boy Fitted Crib Sheet Baby or Toddler Bed Nursery Photo Op - Gray and White Stag. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Hohner COFO Compadre FBbEb Accordion, Orange Bundle with Hohner Bag, Strap, Mini Harmonica, Juliet Music Polish Cloth & Piano Key Stickers. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Dean 6 String Icon X Solid-Body Electric Guitar-Silverburst, (ICONX SVB). This product was bought at the store Dean Guitars.',
#  'The title of the product is MyVolts 9V Power Supply Adaptor Compatible with/Replacement for Casio CTK-1100 Keyboard - US Plug. This product was bought at the store MyVolts.',
#  'The title of the product is The Deluxe Woombie Baby Cocoon Swaddle (Newborn (5-13 lbs), Ballet Pink Ruffle). This product was bought at the store Woombie.',
#  'The title of the product is Graco Signature Series 3-in-1 Modular Stroller Flint. This product was bought at the store Graco.',
#  'The title of the product is Evenflo Triumph DLX Convertible Car Seat - Reservoir (Discontinued by Manufacturer). This product was bought at the store Evenflo.',
#  'The title of the product is Fender American Deluxe Strat Plus MN Mystic Ice Blue Solid-Body Electric Guitar. This product was bought at the store Fender.',
#  'The title of the product is Gibson Les Paul Standard Electric Guitar, Gold Top. This product was bought at the store Gibson.',
#  'The title of the product is Luna Mahogany Tattoo Concert Ukulele LEFTY w/Strings,Tuner & CP, UKE TC MAH L COMP. This product was bought at the store Luna Guitars.',
#  'The title of the product is Kala Brand Music Co. Spalted Mango Satin Concert Ukulele (KA-MG-C), Natural. This product was bought at the store Kala.',
#  "The title of the product is Dr. Brown's New Glass Bottle Set, Pink, 4 Ounce. This product was bought at the store Dr. Brown's.",
#  'The title of the product is HALO Sleepsack Swaddle, Heather Grey/Aqua Tech, Small. This product was bought at the store HALO.',
#  'The title of the product is 2018 UPPAbaby VISTA Stroller, Emmett (Green Melange/Silver/Saddle Leather). This product was bought at the store UPPAbaby.',
#  'The title of the product is Ibanez SR306EBWK 6-String Bass Electric Guitar Package in Weathered Black Finish With Guitars Clip On Tuner and Instrument Cable Bundle. This product was bought at the store Ibanez.',
#  'The title of the product is inktastic Awesome Like My Uncle Baby Bib. This product was bought at the store inktastic.',
#  'The title of the product is Hohner BBBX-E Blues Bender E, Key of E. This product was bought at the store Hohner Accordions.',
#  "The title of the product is Dr. Brown's Natural Flow Standard Glass Bottles, 8 Ounce, 2-Count (Discontinued by Manufacturer). This product was bought at the store Dr. Brown's.",
#  'The title of the product is Dunlop John Petrucci Jazz III Guitar Picks, 6 Pack. This product was bought at the store JIM DUNLOP.',
#  'The title of the product is Halo 100% Cotton Muslin Sleepsack Swaddle Wearable Blanket, Elephant Plaid, Small. This product was bought at the store HALO.',
#  'The title of the product is Summer SwaddleMe WrapSack Blanket, Flower Power, Large. This product was bought at the store SwaddleMe.',
#  'The title of the product is Yamaha YPT400AD Portable Electronic keyboard w/ 61 Full Size touch sensitive keys. This product was bought at the store YAMAHA.',
#  'The title of the product is Fisher-Price Sit-Me-Up Floor Seat - Frog, portable baby chair with toys. This product was bought at the store Fisher-Price.',
#  'The title of the product is Squier Vintage Modified Telecaster Bass Guitar, Maple Fingerboard, Black. This product was bought at the store Fender.',
#  'The title of the product is Remo Drum Set, 20 (P31120-C2). This product was bought at the store Remo.',
#  'The title of the product is ESP LTD ALEXI-600 Scythe Alexi Laiho Signature Electric Guitar. This product was bought at the store ESP.',
#  'The title of the product is Huggies Simply Clean Unscented Baby Wipes, 9 Flip-Top Packs (576 Wipes Total),64 Count (Pack of 9). This product was bought at the store HUGGIES.',
#  'The title of the product is Nuby Thirsty Kids No Spill Flip-It Reflex Stainless Steel Travel Cup, 10 Oz, White. This product was bought at the store Nuby.',
#  'The title of the product is 6-Hole Round Silicone Mold for Chocolate, Cake, Jelly, Pudding, Dome Mousse, Round, Handmade soap (Brick red) 2 Packets. This product was bought at the store XGATML.',
#  'The title of the product is Ernie Ball Nickel Wound Single Guitar Strings 3-Pack .032 Gauge 3-Pack. This product was bought at the store Ernie Ball.',
#  'The title of the product is Fender(R) 235-0500-000 G-DEC(R) 30 Guitar Amp. This product was bought at the store Fender.',
#  'The title of the product is Zip Id Case and Lanyard in Ink Blue. This product was bought at the store XGATML.',
#  'The title of the product is Huggies Pull-Ups Training Pants, Boys, 4T-5T, 21-Count. This product was bought at the store Pull-Ups.',
#  'The title of the product is Pampers Cruisers Diapers Jumbo Pack Size 3 31ct.. This product was bought at the store Pampers.',
#  'The title of the product is Remo 14 Renaissance Diplomat Drumhead. This product was bought at the store Remo.',
#  'The title of the product is Baby Jogger City Mini Stroller in Lime, Gray Frame, BJ11440. This product was bought at the store Baby Jogger.',
#  'The title of the product is PreSonus Revelator io24 Desktop 2x4 USB Type-C Audio / MIDI Interface | Software Pack and Eris E3.5 Pair Studio Monitors with and 1/4 Cables. This product was bought at the store PreSonus.',
#  'The title of the product is decalmile Construction Vehicles Wall Decals Cars Transportation Boys Wall Stickers Baby Nursery Childrens Bedroom Living Room Wall Decor. This product was bought at the store decalmile.',
#  'The title of the product is AC Adapter for Vox Adio Air GT & BS Guitar Bluetooth Combo Amp Power Supply. This product was bought at the store EPtech.',
#  'The title of the product is Latin Percussion Santana Supernatural Mini Conga (Purple). This product was bought at the store Latin Percussion.',
#  'The title of the product is JIM DUNLOP 418R.60 Tortex Standard, Orange, .60mm, 72/Bag. This product was bought at the store JIM DUNLOP.',
#  'The title of the product is Dream On Me Harper 4-In-1 Convertible Crib In Storm Grey, Greenguard Gold & JPMA Certified, 3 Mattress Height Settings. This product was bought at the store Dream On Me.',
#  'The title of the product is Swim Diapers Size 3 (13-24 lb) - Pampers Splashers Disposable Swim Pants, Small, Pack of 2 (Twinpack), 20 Count. This product was bought at the store Pampers.',
#  'The title of the product is Dean Baby ML 7/8 Size Solid Body Electric Guitar Metallic Silver. This product was bought at the store Dean Guitars.',
#  'The title of the product is Aeiniweraabbcc Hille Decor 24 Blue Dogs Plates Birthday Disposable Plate, Birthday Party Supplies Decorations 9 Inch and 7 Inch. This product was bought at the store Aeiniwer.',
#  'The title of the product is Decksaver DSP-PC-X32PRODUCER Protective Cover for Pro Behringer X32 PRODUCER. This product was bought at the store DECKSAVER.',
#  'The title of the product is Nuby Silicone Confetti/Sprinkles First Open Training Cup for Baby - 2oz, 6+ Months. This product was bought at the store Nuby.',
#  'The title of the product is Sabian Cymbal Variety Package, 17 (A1706). This product was bought at the store Sabian.',
#  'The title of the product is Peg Perego Switch Four Stroller. This product was bought at the store Peg Perego.',
#  "The title of the product is Dr. Brown's Options Narrow Bottles, 3 Pack, 8 Ounce, Pink. This product was bought at the store Dr. Brown's.",
#  'The title of the product is Decksaver DS-PC-MCX8000 Denon MCX8000 DJ Controller Cover. This product was bought at the store DECKSAVER.',
#  'The title of the product is Lambs & Ivy Musical Mobile, Garden Safari (Discontinued by Manufacturer). This product was bought at the store Lambs & Ivy.',
#  'The title of the product is Ibanez Yvette Young YY10 Signature Slime Green Sparkle. This product was bought at the store Ibanez.',
#  'The title of the product is Casio LK-270 Premium Lighted Keyboard Pack with Power Supply, Keyboard Stand and Professional Closed Cup Stereo Headphones. This product was bought at the store Casio.',
#  'The title of the product is Munchkin Go Diego Go Insulated Spill Proof Straw Cups 3/Pk -Boys BPA FREE. This product was bought at the store Munchkin.',
#  "The title of the product is Dr. Brown's Soft Spout Transition Cup (6 oz Soft-Spout Transition Cup Assorted (Stage 1 6m+)). This product was bought at the store Dr. Brown's.",
#  'The title of the product is SwaddleDesigns Baby Lovie, Small Security Blanket, Polka Dots with Satin Trim, Lavender. This product was bought at the store SwaddleDesigns.',
#  'The title of the product is Disney Mickey Mouse Clubhouse Slim Sippy Cups, Red/Blue, 2 Count. This product was bought at the store Disney.',
#  'The title of the product is Britax Parkway SGL G1.1 Belt-Positioning Booster Seat, Phantom. This product was bought at the store BRITAX.',
#  'The title of the product is Kala KA-SSTU-C Concert Travel Ukulele Bundle with Gig Bag, Clip-On Tuner, Austin Bazaar Instructional DVD, and Polishing Cloth. This product was bought at the store Kala.',
#  'The title of the product is Construction Cars City Wall Decals Transportation Roads Kids Wall Stickers Baby Nursery Childrens Bedroom Playroom Wall Stickers, Green. This product was bought at the store Generic.',
#  "The title of the product is Dr. Browns Natural Flow Options+ Glass Baby Bottle Sleeves, 100% Silicone, 4 oz, Narrow, Blue. This product was bought at the store Dr. Brown's.",
#  'The title of the product is OMNIHIL 8 Feet AC/DC Power Adapter 9V 1.5A (1500mA) 5.5x2.1millimeters Compatible with Singing MAC Hine SML-283 SML-283P SML283 SML283P SML283BK CDG Karaoke. This product was bought at the store OMNIHIL.',
#  'The title of the product is Epiphone Limited Edition Les Paul Custom Blackback Electric Guitar Antique Ivory. This product was bought at the store Epiphone.',
#  'The title of the product is E & M ENYC Eva NYC Satin Dream Leave In Cream with Keravis and Argan Oil. Detangles Smooths and Moisturizes. For All Hair Types. 5. This product was bought at the store XGATML.',
#  'The title of the product is CHAUVET DJ COLORtube 3.0 EQ Linear Chase/Music Visualizer | LED Lighting. This product was bought at the store CHAUVET DJ.',
#  'The title of the product is Medela SoftfeederTM Sterile - Medela 6100018S. This product was bought at the store Medela.',
#  'The title of the product is Evenflo ProComfort Rightfit Booster Car Seat, Elliot. This product was bought at the store Evenflo.',
#  'The title of the product is Epiphone Les Paul Classic (Ebony). This product was bought at the store Epiphone.',
#  "The title of the product is Carter's Cotton Fitted Crib Sheet, Butterfly/Pink/Purple. This product was bought at the store Carter's.",
#  'The title of the product is Decksaver Cover for Pioneer XDJ-1000. This product was bought at the store DECKSAVER.',
#  'The title of the product is Maclaren Quest Stroller - Black/Silver. This product was bought at the store Maclaren.',
#  'The title of the product is Paiste 16 Formula 602 Paper Thin Crash. This product was bought at the store Paiste.',
#  'The title of the product is Washburn Southwestern Series D46S12K Acoustic Guitar. This product was bought at the store Washburn.',
#  'The title of the product is Gibson Limited Edition Les Paul Classic Custom Electric Guitar, Gold Top. This product was bought at the store Gibson.',
#  'The title of the product is Thirsties Diaper Cover, Ocean, Medium (18-28 lbs) (Discontinued by Manufacturer). This product was bought at the store Thirsties.',
#  'The title of the product is Thirsties Duo Diaper Snap, Blackbird, Size Two (18-40 lbs). This product was bought at the store Thirsties.',
#  'The title of the product is Thirsties Diaper Cover, Baby Bird, Blue, Medium (18-28 lbs). This product was bought at the store Thirsties.',
#  'The title of the product is Medela Tender Care Lanolin Soothing Relief for Sore Nipples - 0.3 oz (Pack of 3 Tube). This product was bought at the store Medela.',
#  'The title of the product is Munchkin Click Lock Decorated Insulated Big Kid Cup, 9 Ounce (2 Pack). This product was bought at the store Munchkin.',
#  "The title of the product is Hal Leonard Jazz Tracks for Singers - Women's Edition (Book/Online Audio). This product was bought at the store Hal Leonard.",
#  'The title of the product is Huggies Little Movers Plus Diapers, Size 3 (198-Count). This product was bought at the store HUGGIES.',
#  'The title of the product is UPPAbaby Vista V2 Stroller - Declan (Oat Melange/Silver/Chestnut Leather) + Upper Adapters + RumbleSeat V2. This product was bought at the store UPPAbaby.',
#  'The title of the product is Pampers ThickCare Unscented Wipes Refill - 7x Box - 504 Count. This product was bought at the store Pampers.',
#  'The title of the product is Thirsties Diaper Cover, Baby Blue, X-Small (6-12 lbs). This product was bought at the store Thirsties.',
#  'The title of the product is GroVia Hybrid Snap Shell Diaper, Peacocks, One Size. This product was bought at the store GroVia.',
#  'The title of the product is American Baby Company Printed 100% Cotton Jersey Knit Fitted Crib Sheet for Standard Crib and Toddler Mattresses, Baby Pink Stars, for Girls. This product was bought at the store American Baby Company.',
#  'The title of the product is UPPAbaby Vista V2 Stroller- Greyson (Charcoal Melange/Carbon/Saddle Leather) + Upper Adapters + RumbleSeat V2- Greyson (Charcoal Melange/Carbon/Saddle Leather). This product was bought at the store UPPAbaby.',
#  'The title of the product is Hohner Accordions Blues Band Harmonica. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Yamaha FG850 Solid Top Acoustic Guitar, Mahogany. This product was bought at the store YAMAHA.',
#  "The title of the product is JIM DUNLOP AALP03 Animals As Leaders Tosin Abasi Jazz III XL, .60mm, White, 6/Player's Pack. This product was bought at the store JIM DUNLOP.",
#  'The title of the product is Hohner M2013BX Rocket Harmonica, Key of G Sharp. This product was bought at the store Hohner Accordions.',
#  'The title of the product is New AC Power Supply Power AC Adapter for Epiphone Electar 10 Guitar Amplifier. This product was bought at the store EPtech.',
#  'The title of the product is Woombie Air, Gray Zebra/Turquoise Trim, Newborn 5-13 Lbs. This product was bought at the store Woombie.',
#  'The title of the product is Korg Keyboard Production Station (405012500). This product was bought at the store Korg.',
#  'The title of the product is JOYO JF-04 High Gain Distortion Guitar Effect Pedal - Bypass, DC 9V and Battery Supported. This product was bought at the store JOYO.',
#  'The title of the product is Fender Redondo Classic - California Series Acoustic Guitar - Hot Rod Red Metallic Finish with Gig Bag. This product was bought at the store Fender.',
#  'The title of the product is Fender Tortuga Ultem Guitar Picks 351 Shape, Tortoise Shell, Heavy, 6-Pack. This product was bought at the store Fender.',
#  'The title of the product is 2018 UPPABaby Cruz Stroller - Jake (Black/Carbon/Black Leather) + Bassinet- Jake (Black/Carbon). This product was bought at the store UPPAbaby.',
#  'The title of the product is Jackson JS32 Dinky DKA Electric Guitar Natural Oil. This product was bought at the store Jackson.',
#  'The title of the product is Britax Allegiance Convertible Car Seat, Prism. This product was bought at the store BRITAX.',
#  'The title of the product is Washburn DK20T w/ Deluxe Gig Bag Acoustic Guitar with Built In Tuner. This product was bought at the store Washburn.',
#  'The title of the product is Squier Mini Stratocaster Electric Guitar, Black, Laurel Fingerboard, Left-Handed. This product was bought at the store Fender.',
#  'The title of the product is Stokke Tripp Trapp Moss Green. This product was bought at the store Stokke.',
#  'The title of the product is Pampers Swaddlers Newborn Diapers Size N 31 Count. This product was bought at the store Pampers.',
#  'The title of the product is Lp Aspire Wood Conga 12 In Natural. This product was bought at the store Latin Percussion.',
#  'The title of the product is CHAUVET DJ LED Lighting (DFIHUB). This product was bought at the store CHAUVET DJ.',
#  "The title of the product is Carter's Jersey Knit Fitted Bassinet Sheet, Leaf/Yellow. This product was bought at the store Carter's.",
#  'The title of the product is Ibanez TMB300 4-String Electric Bass Guitar Metallic Forrest. This product was bought at the store Ibanez.',
#  'The title of the product is (2) Chauvet DJ Wash FX 2 Multi-Purpose Effect Lights with Infrared Remote Control & Carry Bags Package. This product was bought at the store CHAUVET DJ.',
#  'The title of the product is The Kids Room by Stupell Sea Life Blue Growth Chart, 7 x 0.5 x 39, Proudly Made in USA. This product was bought at the store Stupell Industries.',
#  'The title of the product is Latin Percussion LP638 Futurelite II Conga Stand. This product was bought at the store Latin Percussion.',
#  'The title of the product is Wallmonkeys WM84978 Rabbit Bunny Baby Isolated on White Background Peel and Stick Wall Decals (24 in W x 18 in H), Medium. This product was bought at the store Wallmonkeys.',
#  'The title of the product is Squier Mini Jazzmaster Electric Guitar, Daphne Blue, Maple Fingerboard. This product was bought at the store Fender.',
#  'The title of the product is Munchkin Click Lock 7-Ounce Cup Assorted Color. This product was bought at the store Munchkin.',
#  'The title of the product is Fisher-Price Infant-to-Toddler Rocker - Geo Diamonds. This product was bought at the store Fisher-Price.',
#  'The title of the product is Sweet Jojo Designs Changing Pad Cover - Camel and Chocolate Paisley. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Jackson JS32 Rhoads with Floyd Rose Electric Guitar Inferno Red. This product was bought at the store Jackson.',
#  'The title of the product is SwaddleMe by Ingenuity Original Swaddle, Size Large, For Ages 3-6 Months, 14-18 Pounds, Up to 30 Inches Long, 3-Pack Baby Swaddle Blanket Wrap. This product was bought at the store SwaddleMe.',
#  'The title of the product is 2015 Gibson SG Standard in Heritage Cherry. This product was bought at the store Gibson.',
#  'The title of the product is Munchkin Click Lock Bite Proof Sippy Cup, 9 Ounce,2 Count (Pack of 1), Blue/Green. This product was bought at the store Munchkin.',
#  'The title of the product is Britax Marathon ClickTight Convertible Car Seat, Cowmooflage. This product was bought at the store BRITAX.',
#  'The title of the product is Audio-Technica Microphone AT2020 Pro Cardioid Capacitor, Black,Large, XLR. This product was bought at the store Audio-Technica.',
#  'The title of the product is Seventh Generation Baby Diapers for Sensitive Skin, Animal Prints, Size 0 Newborn, 36 count. This product was bought at the store Seventh Generation.',
#  'The title of the product is Graco Dynamo Lite Classic Connect Stroller, Oasis (Discontinued by Manufacturer). This product was bought at the store Graco.',
#  'The title of the product is Britax Marathon G4.1 Convertible Car Seat - Domino. This product was bought at the store BRITAX.',
#  'The title of the product is AMS-Focusrite Liquid Mix 16EQ/Compressor Plug-Ins And Control Surface System For DAWs. This product was bought at the store Focusrite.',
#  'The title of the product is JIM DUNLOP Acoustic Guitar Frets (477P208). This product was bought at the store JIM DUNLOP.',
#  'The title of the product is Binger B31N1726 Replacement Battery Compatible with Asus FX80 FX86 TUF FX504 FX504GE FX504GM FX505 FX505DT FX505DY. This product was bought at the store XGATML.',
#  'The title of the product is Caramel CT904 26inch High Gloss Ebony Tenor Acoustic and Electric Ukulele with Truss Rod. This product was bought at the store Caramel.',
#  'The title of the product is Baby Fanatic Sippy Cup - Philadelphia Phillies. This product was bought at the store Baby Fanatic.',
#  'The title of the product is Hohner M191101 Sonny Terry Heritage Harmonica. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Halo 100% Cotton Muslin Sleepsack Wearable Blanket, Pink Stars, Medium. This product was bought at the store HALO.',
#  'The title of the product is Toca TFA-12MK Freestyle Mechanically Tuned 12-Inch Ashiko Drum - Kente Cloth. This product was bought at the store Toca.',
#  'The title of the product is Evenflo Revolve360 Slim 2-in-1 Rotational Car Seat with Quick Clean Cover (Salem Black). This product was bought at the store Evenflo.',
#  'The title of the product is Kala MK-SS-PNK Makala Shark Soprano Ukulele - Shell Pink Bundle with Gig Bag, Tuner, Instructional DVD, and Austin Bazaar Polishing Cloth. This product was bought at the store Kala.',
#  'The title of the product is Copper Pearl Large Premium Knit Baby Swaddle Receiving Blanket Retro. This product was bought at the store Copper Pearl.',
#  'The title of the product is Kala Journeyman Mahogany U-Bass - Black. This product was bought at the store Kala.',
#  'The title of the product is Yamaha YPT-240 61-Key Keyboard Pack with Headphones, Power Supply, and Stand. This product was bought at the store YAMAHA.',
#  'The title of the product is Epiphone Limited Edition Les Paul Special-I Electric Guitar Worn Cherry. This product was bought at the store Epiphone.',
#  'The title of the product is Britax Marathon G4.1 Convertible Car Seat, Pink Giraffe. This product was bought at the store BRITAX.',
#  'The title of the product is Huggies Simply Clean Fragrance Free Baby Wipes Refill, 672 Count. This product was bought at the store HUGGIES.',
#  'The title of the product is AC Adapter for HP Envy 15-k220nr 15-k227cl Notebook 19.5V 4.62A 90W Laptop Power Supply Cord Cable Battery Charger Mains PSU. This product was bought at the store EPtech.',
#  'The title of the product is Thirsties Duo Fab Fitted Cloth Diapers, Meadow, Size Two (18-40 lbs) (Discontinued by Manufacturer). This product was bought at the store Thirsties.',
#  'The title of the product is Pampers Baby Dry Size 3 Diapers Value Pack 144 Count. This product was bought at the store Pampers.',
#  'The title of the product is Fender Acoustic Steel-String Guitars, Right, Natural, Full Size (09712107211). This product was bought at the store Fender.',
#  'The title of the product is Pampers Swaddlers Disposable Baby Diapers Size 5, 2 Month Supply (2 x 132 Count) with Sensitive Water Based Baby Wipes, 12X Pop-Top Packs (864 Count). This product was bought at the store Pampers.',
#  'The title of the product is Fender American Professional II Telecaster - Roasted Pine with Maple Fingerboard. This product was bought at the store Fender.',
#  'The title of the product is Fender Limited Edition Blues Junior III 15-Watt 1x12-Inch Guitar Combo Amplifier - Silver Noir Two-Tone. This product was bought at the store Fender.',
#  'The title of the product is Thirsties One Size All In One Cloth Diaper, Snap Closure, Aqua. This product was bought at the store Thirsties.',
#  'The title of the product is RoomMates RMK3776SCS Puppy Dog Pals Peel and Stick Wall Decals 9 x 17.375,Blue, Brown, Red, Yellow. This product was bought at the store RoomMates.',
#  'The title of the product is Squier Classic Vibe 70s Jaguar Electric Guitar, Surf Green, Laurel Fingerboard. This product was bought at the store Fender.',
#  'The title of the product is Storkcraft Maxwell Convertible Crib (Espresso) GREENGUARD Gold Certified, Converts to Toddler Bed and Daybed, Fits Standard Full-Size Crib Mattress, Classic Crib with Traditional Sleigh Design. This product was bought at the store Stork Craft.',
#  'The title of the product is UPPAbaby 2013 G-Lite Stroller, Jake Black (Older Version) (Discontinued by Manufacturer). This product was bought at the store UPPAbaby.',
#  'The title of the product is Fender Player Plus 5-String Jazz Bass, 3-Color Sunburst, Pau Ferro Fingerboard. This product was bought at the store Fender.',
#  'The title of the product is Jackson JS3V Concert JS Series Electric Bass Guitar - Black. This product was bought at the store Fender.',
#  'The title of the product is Gibraltar 8700PK Drum Set Mounting Flat-Base Hardware. This product was bought at the store GIBRALTAR.',
#  'The title of the product is SwaddleDesigns Cotton Muslin Swaddle Blankets, Set of 4, Green Woodland. This product was bought at the store SwaddleDesigns.',
#  'The title of the product is Ibanez RG421 Electric Guitar Blackberry Sunburst. This product was bought at the store Ibanez.',
#  "The title of the product is Dr. Browns Natural Flow Anti-Colic Options+ Wide-Neck Glass Baby Bottle 5 oz/150 mL, with Level 1 Slow Flow Nipple, 1 Pack, 0m+. This product was bought at the store Dr. Brown's.",
#  'The title of the product is Takamine Pro Series 3 P3NC NEX Body Acoustic Electric Guitar with Case. This product was bought at the store Takamine.',
#  'The title of the product is ENERGYSOUND Frosted D Note Sacral Chakra Quartz Crystal Singing Bowl 10 inch mallet and o-ring included. This product was bought at the store ENERGYSOUND.',
#  'The title of the product is Fitted Crib Sheet for Outdoor Adventure Baby/Toddler Bedding - Nature Fox Bear Animals Boys Print. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Schecter Demon-7 7-String Electric Guitar. This product was bought at the store Schecter.',
#  'The title of the product is HALO Big Kids Sleepsack Micro Fleece Wearable Blanket, TOG 1.0, Pink, 2T-3T. This product was bought at the store HALO.',
#  'The title of the product is The First Years Winnie The Pooh Soft Spout Trainer Cup, 7 Ounce (Discontinued by Manufacturer). This product was bought at the store The First Years.',
#  'The title of the product is inktastic Grandma and Grandpa Love Me- Little Fox Baby Bib. This product was bought at the store inktastic.',
#  'The title of the product is Yamaha FS720S Small Body Solid Top Acoustic Guitar - Mahogany, Black. This product was bought at the store YAMAHA.',
#  'The title of the product is Seventh Generation Diaper Stg3 16-28lbs. This product was bought at the store Seventh Generation.',
#  'The title of the product is Evenflo Triumph 65 LX Convertible Car Seat, Santee (Discontinued by Manufacturer) (Discontinued by Manufacturer). This product was bought at the store Evenflo.',
#  'The title of the product is Storkcraft Verona 4-in-1 Fixed Side Convertible Crib, Cherry. This product was bought at the store Stork Craft.',
#  "The title of the product is JIM DUNLOP 433P1.14 Ultex Sharp, 1.14mm, 6/Player's Pack. This product was bought at the store JIM DUNLOP.",
#  'The title of the product is Ibanez IJSR190N Jumpstart Bass Black Night w/10W Amp, Tuner, Strap, Cable, & Gig Bag. This product was bought at the store Ibanez.',
#  'The title of the product is Lanikai LU-21TE Tenor Acoustic Electric Ukulele. This product was bought at the store Lanikai.',
#  'The title of the product is DR Handmade Strings, Bass Guitar Strings (SNMR-45). This product was bought at the store DR Strings.',
#  'The title of the product is BIBS Pacifiers - Set of 2 | Colour Pacifier with Anatomical Nipple | BPA-Free Natural Rubber | Made in Denmark | Baby Blue/Petrol, 0-6 Months. This product was bought at the store Bibs.',
#  'The title of the product is Sabian AAX 16 Inch Bright Crash. This product was bought at the store Sabian.',
#  'The title of the product is Halo Sleepsack Cable Knit Sweater Wearable Blanket, Pink Bird, Small. This product was bought at the store HALO.',
#  'The title of the product is Nuby Natural Wood Teether with Soft Silicone, Minimalist Design Easy to Clean, Giraffe. This product was bought at the store Nuby.',
#  'The title of the product is Lambs and Ivy Luv Bugs Picture Frame, Plum (Discontinued by Manufacturer). This product was bought at the store Lambs & Ivy.',
#  'The title of the product is Hohner 38N Mini Harmonica Necklace. This product was bought at the store Hohner Accordions.',
#  'The title of the product is The Original Woombie Purple Stripe Navy Trim Newborn 5-13 Swaddle Blanket. This product was bought at the store Woombie.',
#  "The title of the product is inktastic Grandpa's Little Helper Baby Bib. This product was bought at the store inktastic.",
#  'The title of the product is SABIAN 16 HHX Complex Thin Crash. This product was bought at the store Sabian.',
#  'The title of the product is Storkcraft Venetian 4-in-1 Fixed Side Convertible Crib, Cherry. This product was bought at the store Stork Craft.',
#  'The title of the product is On-Stage DS6213 Desktop Gooseneck Microphone Stand,Black. This product was bought at the store OnStage.',
#  'The title of the product is Gretsch 346 Classic Celluloid Guitar Picks, 50 Pack, Orange, Heavy. This product was bought at the store Fender.',
#  'The title of the product is HALO Sleepsack, 100% Cotton, Loops Pink, Size Medium. This product was bought at the store HALO.',
#  'The title of the product is Dean ZERO AODII Dave Mustaine Electric Guitar - Angel of Death II. This product was bought at the store Dean Guitars.',
#  'The title of the product is Dream On Me Jayden 4 in 1 Convertible Portable Crib w/ Changer with Dream On Me 3 Portable Crib Mattress, White. This product was bought at the store Dream On Me.',
#  'The title of the product is Copper Pearl Large Premium Knit Baby Swaddle Receiving Blanket Dash. This product was bought at the store Copper Pearl.',
#  'The title of the product is Caramel 23 inch CC103A Zebra Wood High Gloss Concert Ukulele for Beginners Professional Ukele Ukalalee Padded Gig Bag Strap Kit. This product was bought at the store Caramel.',
#  'The title of the product is Ibanez SR375 5-String Electric Bass Guitar. This product was bought at the store Ibanez.',
#  'The title of the product is HALO SleepSack 100% Cotton Wearable Blanket. This product was bought at the store HALO.',
#  'The title of the product is LT120F After Service Version Fresh Air Filter Replacement Part (1pk) - compatible with 469918 9918 ADQ73214404. This product was bought at the store CHDENUO.',
#  'The title of the product is Dean V Dave Mustaine End Game Electric Guitar. This product was bought at the store Dean Guitars.',
#  'The title of the product is Luna Guitars Honu Tribal Turtle Tenor Ukulele Satin Natural, Tenor. This product was bought at the store Luna Guitars.',
#  'The title of the product is Fender JMJ Road Worn Mustang Bass, Faded Daphne Blue, Rosewood Fingerboard. This product was bought at the store Fender.',
#  'The title of the product is Squier J Mascis Jazzmaster Electric Guitar, Vintage White, Laurel Fingerboard. This product was bought at the store Fender.',
#  'The title of the product is Odyssey FZMIXDECK Flight Zone Numark Mixdeck Case. This product was bought at the store ODYSSEY.',
#  'The title of the product is Maclaren Techno Stroller XT Stroller, Persian Rose (Discontinued by Manufacturer). This product was bought at the store Maclaren.',
#  "The title of the product is Dr. Browns Milestones 100% Silicone Baby Bottle Handles, Wide-Neck, Light Pink, Ecru, Black, 3 Pack, 4m+. This product was bought at the store Dr. Brown's.",
#  'The title of the product is inktastic My 1st Halloween Witch Spider Baby Bib. This product was bought at the store inktastic.',
#  'The title of the product is Blackstar 10W Digital Stereo Combo (IDCORE10V2). This product was bought at the store Blackstar.',
#  'The title of the product is The Kids Room by Stupell Rainbow Chalkboard Playroom Rules Rectangle Wall Plaque, 11 x 0.5 x 15, Proudly Made in USA. This product was bought at the store Stupell Industries.',
#  'The title of the product is UPPABaby Cruz Stroller - Sydney (Yellow/Grey). This product was bought at the store UPPAbaby.',
#  'The title of the product is Jackson JS Series RR Minion JS1X, Amaranth Fingerboard, Satin Black Electric Guitar. This product was bought at the store Jackson.',
#  'The title of the product is DECOWALL DWG-601N_B Modern Butterfly Graphic Kids Wall Decals Wall Stickers Peel and Stick Removable Wall Decals for Kids Nursery Bedroom Living Room (Black). This product was bought at the store DECOWALL.',
#  'The title of the product is B.C. Rich PXBS Electric Guitar, Shadow. This product was bought at the store B.C. Rich.',
#  'The title of the product is Hohner Golden Melody Harmonica, Key of E. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Dunlop Gel Guitar Picks X-H, Extra Heavy, 1.2 mm 1 Dozen. This product was bought at the store JIM DUNLOP.',
#  'The title of the product is mcyiqihai ONOW Full Drill Wolf Diamond Painting Kit, Little Wolf DIY Diamond Rhinestone Painting Kits for Adults and Beginner Diamond Arts Craft Home Decor,Late Autumn. This product was bought at the store XGATML.',
#  'The title of the product is Fender Player Stratocaster SSS Electric Guitar, Capri Orange, Maple Fingerboard, Left-Handed. This product was bought at the store Fender.',
#  'The title of the product is BathroomStorageBox Farmhouse Wooden Bathroom Box Sign,Funny Wooden Rustic Toilet Paper Holder,Home Decor Box for Bathroom, Kitchen,Table Wall and Counter Bedroom Decor (White). This product was bought at the store XGATML.',
#  'The title of the product is PRS SE Custom 24 Faded Blue Burst. This product was bought at the store PRS.',
#  'The title of the product is Graco Soothing System Gliding Swing, Finland. This product was bought at the store GRACO.',
#  'The title of the product is Britax Boulevard G4.1 Convertible Car Seat, Harlequin. This product was bought at the store BRITAX.',
#  'The title of the product is Delta Children Toddler Guardrail, White. This product was bought at the store Delta Children.',
#  "The title of the product is Johnson's Baby Cream 50 grams (1.8 oz). This product was bought at the store Johnson's Baby.",
#  'The title of the product is Ibanez Iron Label ARZIR20 Electric Guitar (White). This product was bought at the store Ibanez.',
#  'The title of the product is Ernie Ball Electric Guitar Pack (EB 1126 .026 Nickel Wound String Single). This product was bought at the store Ernie Ball.',
#  'The title of the product is Evenflo AMP High Back Car Seat Booster, Blue Angles. This product was bought at the store Evenflo.',
#  'The title of the product is Sweet Jojo Designs Baby/Kids Clothes Laundry Hamper for White and Navy Hotel Bedding. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Large Premium Knit Baby 3 Layer Stretchy Quilt Blanket Chip by Copper Pearl. This product was bought at the store Copper Pearl.',
#  "The title of the product is inktastic My Daddy Graduated and I'm Super Proud Baby Bib. This product was bought at the store inktastic.",
#  'The title of the product is Fender Squier Vintage Modified Jaguar Beginner Short Scale Electric Bass Guitar - Black. This product was bought at the store Fender.',
#  'The title of the product is Schecter C-1 FR-S SLS Elite - Antique Fade Burst. This product was bought at the store Schecter.',
#  'The title of the product is Floral Sleep Sack - Medium. This product was bought at the store HALO.',
#  'The title of the product is The First Years Take & Toss Spill-Proof Sippy Cups - Multicolor - 10 oz - 4 ct. This product was bought at the store The First Years.',
#  'The title of the product is Hohner 595BX-C Harmonica, Key of C. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Delta Children Westminster 6-in-1 Convertible Baby Crib, Greenguard Gold Certified, Grey. This product was bought at the store Delta Children.',
#  'The title of the product is Pampers Cruisers Disposable Diapers Size 5, 108 Count, ECONOMY. This product was bought at the store Pampers.',
#  'The title of the product is Maclaren Quest Sport Stroller, Black/Champagne (Discontinued by Manufacturer). This product was bought at the store Maclaren.',
#  'The title of the product is Musiclily Pro 54mm Guitar Strat Tremolo Bridge Assembly Set for Fender American Standard Modern Stratocaster Guitar Replacement, Gold. This product was bought at the store Musiclily.',
#  'The title of the product is Schecter BlackJack V-1 Electric Guitar (Gloss Black). This product was bought at the store Schecter.',
#  'The title of the product is HALO SleepSack 100% Cotton Wearable Blanket, Blue, X-Large (Discontinued by Manufacturer). This product was bought at the store HALO.',
#  'The title of the product is Blackstar ID Core V3 20W Digital Modeling Amplifer. This product was bought at the store Blackstar.',
#  'The title of the product is Munchkin Dora the Explorer Insulated Straw Cup, 9 Ounce, Colors May Vary (Discontinued by Manufacturer). This product was bought at the store Munchkin.',
#  'The title of the product is Gibson Firebird 2010 Electric Guitar, Vintage Sunburst - Chrome Hardware. This product was bought at the store Gibson.',
#  'The title of the product is Movie Photos 8 x 10 Judge Judy Framed. This product was bought at the store Aeiniweraabbcc.',
#  'The title of the product is NUK Learner Cup, 5oz, 2-Pack, Flamingo. This product was bought at the store NUK.',
#  'The title of the product is HALO 100% Cotton Muslin Sleepsack Swaddle, Elephant Plaid, Newborn. This product was bought at the store HALO.',
#  'The title of the product is Drillmaster 18 Volt NiCD Charger. This product was bought at the store XGATML.',
#  'The title of the product is Seymour Duncan SHPR-1b P-Rails Pickup - Bridge. This product was bought at the store Seymour Duncan.',
#  "The title of the product is Gibson SG Tribute 60's Guitar Vintage Sunburst Vintage Gloss. This product was bought at the store Gibson.",
# ...
#  'The title of the product is Seventh Generation Free and Clear Baby Diapers, Stage 2, 40 Count (Pack of 4). This product was bought at the store Seventh Generation.',
#  'The title of the product is Seymour Duncan Mick Thomson Blackouts Electric Guitar Electronics. This product was bought at the store Seymour Duncan.',
#  'The title of the product is On-Stage GS7800 U-Mount Microphone Stand Guitar Hanger. This product was bought at the store OnStage.',
#  'The title of the product is Casio CTK900 Keyboard with Power Supply, Stand and Akai Digital Chord Finder. This product was bought at the store Casio.',
#  'The title of the product is HONEST Club Box Clean Conscious Diapers Fall Seasonal, Prairie Petals, Size 6, 44ct. This product was bought at the store The Honest Company.',
#  'The title of the product is UPPAbaby Cruz Stroller, Denny (Older Version) (Discontinued by Manufacturer). This product was bought at the store UPPAbaby.',
#  'The title of the product is Yamaha YPT400MS Portable Electronic Keyboard with 61 Full Size Touch Sensitive Keys and Keyboard Stand. This product was bought at the store YAMAHA.',
#  'The title of the product is HALO SleepSack Micro-Fleece Early Walker Wearable Blanket, Baby Blue, Large (Discontinued by Manufacturer). This product was bought at the store HALO.',
#  'The title of the product is Grovia Organic Cotton Newborn All In One (AIO) Diaper - New Style - Surf. This product was bought at the store GroVia.',
#  'The title of the product is 6V 1A AC/AC Adapter for Maxim MA410611 MA350602 ATLINKS 5-2495A RCA 25403RE3 25202RE3 JT CZJUTAI JT-6V1200 Ktec KA12A060120035U HoMedics NMSQ-210 G6-800 NMSQ-200 6VAC. This product was bought at the store EPtech.',
#  'The title of the product is Sweet Jojo Designs Pink and Green Jungle Friends Stripe Fabric Memory/Memo Photo Bulletin Board. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Pampers Baby Wipes Refills, Baby Fresh Scent, 80-Count Packages (Pack of 10) (800 Wipes). This product was bought at the store Pampers.',
#  'The title of the product is Bibs BPA-Free Natural Rubber Baby Pacifier | Made in Denmark (Mint/White/Peach/Mocha, 6-18 Months) 4-Pack. This product was bought at the store Bibs.',
#  'The title of the product is Latin Percussion CP265B 11-Inch Supreme Rawhide Conga Head. This product was bought at the store Latin Percussion.',
#  'The title of the product is Pickboy PBCFSP100 Hand-Shaped Guitar Picks, Natural Horn, Triangle, 1 Pick. This product was bought at the store Pickboy.',
#  'The title of the product is Lifefactory Glass Baby Bottle w/ Silicone Sleeve :: Orange 9oz.. This product was bought at the store Lifefactory.',
#  'The title of the product is Ibanez SR255 5-String Electric Bass Guitar (Pearl White). This product was bought at the store Ibanez.',
#  'The title of the product is Left Handed - Caramel CB418L Curly Mahogany Baritone Acoustic Electric Ukulele with Truss Rod with D-G-B-E Strings. This product was bought at the store Caramel.',
#  'The title of the product is Stokke Tripp Trapp Complete Bundle - 2 Items: Tripp Trapp Highchair & Tripp Trapp Babyset Natural. This product was bought at the store Stokke.',
#  'The title of the product is Hohner 53 Tremolo Harmonica, Minor E. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Other Powerstroke 77 Coated Snare Drumhead-Top Clear Dot, 14 (P70114-C2-U). This product was bought at the store Remo.',
#  'The title of the product is Maclaren Techno XT Stroller, Black (Discontinued by Manufacturer). This product was bought at the store Maclaren.',
#  'The title of the product is Evenflo Maestro Sport Harness Booster Car Seat, Crestone Peaks. This product was bought at the store Evenflo.',
#  'The title of the product is Squier J5 Telecaster Electric Guitar Frost Gold. This product was bought at the store Fender.',
#  'The title of the product is GenericJINCHENGWU Red Heart (Coats) Yarn - Fashion Soft - 6 Pack (Camel). This product was bought at the store XGATML.',
#  'The title of the product is Delta Children Abby 4-in-1 Convertible Baby Crib, Grey. This product was bought at the store Delta Children.',
#  'The title of the product is Other Drum Set, 8-inch (BE0008-ES). This product was bought at the store Remo.',
#  "The title of the product is D'Andrea CP23 TH BLK Guitar Picks, 144-Piece, Black, Assorted Symbols, Thin. This product was bought at the store D'Andrea.",
#  'The title of the product is Bulk 12 Sets, Ernie Ball, Electric Guitar Strings, Hybrid Slinky Gauge (9-46). This product was bought at the store Ernie Ball.',
#  'The title of the product is Fender 351 Shape Medium Classic Celluloid Picks, 12-Pack, White Moto for electric guitar, acoustic guitar, mandolin, and bass. This product was bought at the store Fender.',
#  'The title of the product is Peg Perego Uno Stroller - Mod Verde. This product was bought at the store Peg Perego.',
#  'The title of the product is Sabian 450031 B8 Performance Set With Free 14 - Inch Crash. This product was bought at the store Sabian.',
#  'The title of the product is Grey, Black and Red Woodland Plaid and Moose Baby Kid Clothes Laundry Hamper for Rustic Patch Collection by Sweet Jojo Designs. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is PRS SE Custom 24 Roasted Maple Limited Electric Guitar (Trampas Green). This product was bought at the store PRS.',
#  'The title of the product is Hohner Chrometta 12 Harmonica G. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Huggies Soft Skin Baby Wipes Tub, 256 Total Wipes 64-Count (Pack of 4). This product was bought at the store HUGGIES.',
#  'The title of the product is Tommee Tippee No Knock Cup 190ml (Dog). This product was bought at the store Tommee Tippee.',
#  'The title of the product is Copper Pearl Large Premium Knit Baby Swaddle Receiving Blanket Black and White Tribe. This product was bought at the store Copper Pearl.',
#  'The title of the product is Britax Boulevard ClickTight Convertible Car Seat, Cool Flow Teal, 20.5x23x23.5 Inch (Pack of 1). This product was bought at the store BRITAX.',
#  'The title of the product is Halo SleepSack, Micro-fleece, Oh Deer, Blue, Medium. This product was bought at the store HALO.',
#  "The title of the product is Carter's Elephants Velour Sherpa Blanket, Navy/Green (Discontinued by Manufacturer). This product was bought at the store Carter's.",
#  'The title of the product is Odyssey FR1200BK Red Designer Series DJ Turntable Case. This product was bought at the store ODYSSEY.',
#  'The title of the product is MyVolts 12V Power Supply Adaptor Compatible with/Replacement for Korg SP-170S Keyboard - US Plug. This product was bought at the store MyVolts.',
#  'The title of the product is Nuby BPA FREE No-Spill Cup w/ Soft Spout & Handles, 1-pk, Boy Colors. This product was bought at the store Nuby.',
#  'The title of the product is Fender Artist Series Tim Armstrong Deluxe Concert Acoustic-Electric Guitar. This product was bought at the store Fender.',
#  'The title of the product is HALO SleepSack Micro Fleece Wearable Blanket, Print Girl, Large (Discontinued by Manufacturer). This product was bought at the store HALO.',
#  'The title of the product is Squier by Fender Vintage Modified Jaguar Beginner Short Scale Electric Bass Guitar - Candy Apple Red. This product was bought at the store Fender.',
#  'The title of the product is Medela PersonalFit Breastshields (2), Size: X-Large (30mm) in Retail Packaging (Factory Sealed) #87075. This product was bought at the store Medela.',
#  'The title of the product is ESP LTD Michael Wilton Signature Guitar Skull graphic. This product was bought at the store ESP.',
#  'The title of the product is Kala KA-CE Satin Mahogany Concert Electric Ukulele. This product was bought at the store Kala.',
#  "The title of the product is Carters Wrap Me Up Receiving Blanket, 4 Pack, Magenta (Discontinued by Manufacturer). This product was bought at the store Carter's.",
#  'The title of the product is Evenflo Gold SensorSafe EveryStage Smart All-in-One Convertible Car Seat, Garnet, 21 x 31.5 x 20.5. This product was bought at the store Evenflo.',
#  'The title of the product is Baby Jogger City Mini ZIP Stroller. This product was bought at the store Baby Jogger.',
#  "The title of the product is Dunlop 47P1N Nylon Jazz I, Red, 1.10mm, 6/Player's Pack. This product was bought at the store JIM DUNLOP.",
#  'The title of the product is Dunlop BOBPT01M Bob Marley Rasta Pick Tin, Assorted, Medium, 6 Picks/Tin. This product was bought at the store JIM DUNLOP.',
#  'The title of the product is Oscar Schmidt OU220SWK Concert Ukulele. This product was bought at the store Oscar Schmidt.',
#  'The title of the product is Pirastro Evah Pirazzi Gold Violin E String - Stainless Steel - Medium Gauge - Ball End. This product was bought at the store Pirastro.',
#  'The title of the product is Paiste PST 7 Thin Crash 17 in.. This product was bought at the store Paiste.',
#  'The title of the product is Dream On Me Classic 3 in 1 Convertible Stationary Side Crib with Dream On Me Spring Crib and Toddler Bed Mattress, Twilight. This product was bought at the store Dream On Me.',
#  'The title of the product is Lanikai LUTU-21P Mahogany Soprano Pineapple Ukulele, Natural. This product was bought at the store Lanikai.',
#  'The title of the product is Ibanez SR256 6-String Bass Guitar Pearl White. This product was bought at the store Ibanez.',
#  'The title of the product is Sweet Jojo Designs Baby/Kids Clothes Laundry Hamper for Turquoise and Gray Chevron Zig Zag Bedding. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Nuby Ice Gel Teether Keys. This product was bought at the store Nuby.',
#  'The title of the product is Nuby Cell Phone Popper Sensory Play Teether Toy - 3+ Months, 1pk Assorted Neutral Colors. This product was bought at the store Nuby.',
#  'The title of the product is Huggies Pull-Ups Training Pants with Cool Alert Wetness Liner, Boys, 4T-5T, 33-Count. This product was bought at the store Pull-Ups.',
#  'The title of the product is JOYO Overdrive Guitar Effect Pedal with Multi-mode and Built-in Noise Gate for Electric Guitar Bass True Bypass Design (ARGOS OVERDRIVE JF-23). This product was bought at the store JOYO.',
#  'The title of the product is Maclaren Quest Mod Stroller, Navy and Kelly Green (Discontinued by Manufacturer). This product was bought at the store Maclaren.',
#  'The title of the product is Seymour Duncan - 11201-01-RwRp-L - SSL-1L Vntg Stag Strat RwRp L. This product was bought at the store Seymour Duncan.',
#  'The title of the product is Oscar Schmidt OU2TTAT-A-U Tenor Ukulele Satin with Tattoo Bundle with Gig Bag, Strings, Tuner, Strap, Instructional DVD, and Austin Bazaar Polishing Cloth. This product was bought at the store Oscar Schmidt.',
#  'The title of the product is Britax Parkway SG-2 Booster Seat. This product was bought at the store BRITAX.',
#  "The title of the product is Gibson USA SGTR6LE5RC1SG Tribute 60's Min-ETune Ebony Vintage Gloss Left Hand. This product was bought at the store Gibson.",
#  'The title of the product is Odyssey FZCDJ Flight Zone Ata Case for Single Large Format CD Player. This product was bought at the store ODYSSEY.',
#  'The title of the product is Seventh Generation Free and Clear, Unbleached Baby Diapers, Stage 4, 54 Count, Packaging May Vary. This product was bought at the store Seventh Generation.',
#  'The title of the product is Tommee Tippee Sippee Cup, Pink and Purple, 10 Ounce, 2 Count. This product was bought at the store Tommee Tippee.',
#  'The title of the product is HQRP AC Adapter Compatible with PignosePA7 7-100 7-100AR Portable Guitar Amplifier Amp Power Supply Cord PA-7 Legendary + Euro Plug Adapter. This product was bought at the store HQRP.',
#  'The title of the product is Munchkin Simple Clean Toddler Straw Cup, 10 Ounce, 2 Count (Pack of 1), Blue/Green. This product was bought at the store Munchkin.',
#  'The title of the product is Sweet Jojo Designs 11-Piece Modern White and Gold Trellis Lattice Girls Baby Bedding Crib Set Without Bumper. This product was bought at the store Sweet Jojo Designs.',
#  'The title of the product is Nuby 2-Pack 9-oz Insulated Cool Sipper, Girl, BPA-Free. This product was bought at the store Nuby.',
#  'The title of the product is Ibanez ARZ Series ARZ200FM Electric Guitar Cherry Red Sunburst. This product was bought at the store Ibanez.',
#  'The title of the product is Huggies Diapers Little Movers Disney Size 4 (22-37 lb) 24 CT (Pack of 12). This product was bought at the store HUGGIES.',
#  'The title of the product is Graco FastAction Fold Jogger Click Connect Travel System, Chili Red (Discontinued by Manufacturer). This product was bought at the store GRACO.',
#  'The title of the product is Graco Modes Sport Travel System, Tangerine. This product was bought at the store Graco.',
#  'The title of the product is ESP LTD V-307 Black Satin 7 String Guitar. This product was bought at the store ESP.',
#  'The title of the product is UPPAbaby G-Lite Stroller, Jake (Discontinued by Manufacturer) (Discontinued by Manufacturer). This product was bought at the store UPPAbaby.',
#  'The title of the product is Latin Percussion LPA647-AW Conga Drum Natural / Black. This product was bought at the store Latin Percussion.',
#  'The title of the product is Pampers Easy Ups Training Pants Pull On Disposable Diapers for Boys. This product was bought at the store Pampers.',
#  'The title of the product is Makala Baritone Mahogany Ukulele by Kala (MK-B). This product was bought at the store Kala.',
#  'The title of the product is Epiphone SG Special with Chrome Hardware and KillPot, Cherry. This product was bought at the store Epiphone.',
#  'The title of the product is CASIO Electric Keyboard 76 WK-220 (Japan Import). This product was bought at the store Casio.',
#  'The title of the product is Philips Avent: My Twist n Sip Cup, Pink 9 oz. This product was bought at the store PHILIPS.',
#  'The title of the product is Gibson Les Paul Traditional Honey Burst. This product was bought at the store Gibson.',
#  'The title of the product is On Stage SMS7650 Hex-Base Studio Boom Microphone Stand. This product was bought at the store OnStage.',
#  'The title of the product is Fender Narrow/Tall Guitar Frets, 24-Pack. This product was bought at the store Fender.',
#  'The title of the product is HALO Sleepsack 2-in-1 Swaddle - Animals NB (0-3 Months). This product was bought at the store HALO.',
#  'The title of the product is Peg-Perego Pliko P3 Compact Stroller, Pois Black (Discontinued by Manufacturer). This product was bought at the store Peg Perego.',
#  'The title of the product is Hohner Pro Harp Harmonica, Key of G. This product was bought at the store Hohner Accordions.',
#  'The title of the product is Ibanez Standard SR300EBL Left-handed Bass Guitar - Weathered Black. This product was bought at the store Ibanez.',
#  'The title of the product is Lambs & Ivy Classic Snoopy Musical Baby Crib Mobile Soother Toy - Black/Yellow. This product was bought at the store Lambs & Ivy.',
#  'The title of the product is Dream On Me Lucas Mini Modern Crib with Rounded Spindles. This product was bought at the store Dream On Me.',
#  'The title of the product is DR Strings DDT Bass Guitar Strings (DDT5-45). This product was bought at the store DR Strings.',
#  'The title of the product is Chauvet Dj COLORstrip Mini RGB 4-Channel LED Dam Linear Wash Light w/Automated & Sound-Active Programs. This product was bought at the store CHAUVET DJ.',
#  'The title of the product is UPPAbaby G-Luxe Stroller, Harrison (Discontinued by Manufacturer). This product was bought at the store UPPAbaby.',
#  'The title of the product is Paiste PST 7 Crash 16 in.. This product was bought at the store Paiste.',
#  "The title of the product is Carter's Brown Safari Monkey Snuggle Buddy Security Blanket. This product was bought at the store Carter's.",
#  ...]

# %% [markdown]
# ## Generating Predictions and Extracting Details
#
# In this cell, we process the test data in batches to generate predictions and extract attribute details:
#
# - **`batch_size`**: The number of samples processed in each batch, set to `128`.
#
# - **`generated_details`**: List to store extracted details from generated texts.
# - **`target_details`**: List to store extracted details from target texts.
#
# ### Processing Loop
#
# We iterate over the test data in batches:
# 1. **Batch Extraction**: For each batch of inputs, we generate predictions using the `generate_text` function.
# 2. **Details Extraction**: For each generated text and corresponding label, we extract and append details using the `extract_details` function.
#
# **Note**: The `batch_labels` are included here for completeness, but they are not used in this code snippet for generating predictions.
#
# Finally, a message is printed to indicate that the extraction of generated information is complete.

# %%
batch_size = 64
generated_details = []

for i in tqdm(range(0, len(test_data), batch_size), desc="Processing test data"):
    batch_inputs = test_data[i:i+batch_size]

    generated_texts = generate_text(batch_inputs)

    for generated_text in generated_texts:
        generated_details.append(extract_details(generated_text))

print('Generated info extracted.............')
# Out:
# Processing test data: 100%|██████████| 128/128 [00:43<00:00,  2.92it/s]
# Generated info extracted.............

# %%
generated_text
# Out:
# "details_Manufacturer: Dr. Brown's"

# %%
generated_details
# Out:
# ['The Holster Store',
#  "Carter's",
#  'XGATML',
#  'SAMSUNG',
#  'Aomeiwer',
#  'EATON',
#  'Seymour Duncan',
#  'Odyssey',
#  'SwaddleDesigns',
#  'Huggies',
#  'Stupell Industries',
#  'AIRWAY',
#  'CHAUVET DJ',
#  'decalmile',
#  'Aden + Anais',
#  'Pampers',
#  'EATON',
#  'EPtech',
#  'Nuby',
#  'Jackson',
#  'Hohner',
#  'Pampers',
#  'Jackson',
#  'GRAPHICS & MORE',
#  'OMG SPORTS',
#  'Thirsties',
#  'LOP',
#  'Gibson',
#  'XGATML',
#  'SwaddleDesigns',
#  'Fender',
#  'Baby Jog',
#  'Kala',
#  'Fender',
#  'Jojo Designs, LLC',
#  'JIM DUNLOP',
#  'Seymour Duncan',
#  'decalmile',
#  'Seymour Duncan',
#  'The First Success',
#  'Seymour Duncan',
#  'Graco',
#  'Pirasty',
#  'EATON',
#  'ELECTRONICS',
#  'Aomeiwer',
#  'The Regatta Group DBA Beauty Depot',
#  'XGATML',
#  'Stupell Industries',
#  'Pampers',
#  'aden',
#  'Ibanez',
#  'Prins',
#  'Inktastic',
#  'The HONEST COMPANY',
#  'EATON',
#  'K-MuskuloAABBCC',
#  'Jojo Designs, LLC',
#  'PreSonus',
#  'BRITAX',
#  'DECOWALL',
#  'Pampers',
#  'Jojo Designs, LLC',
#  'Hohner',
#  'Dean',
#  'MyVolts',
#  'Woombie',
#  'Graco',
#  'OUTLOOK GROUP CORP',
#  'Fender',
#  'Gibson',
#  'Moon',
#  'Kala',
#  "Dr. Brown's",
#  'HaLO',
#  'UPPAbaby',
#  'Ibanez',
#  'Inktastic',
#  'Hohner',
#  "Dr. Brown's",
#  'JIM Dunlop',
#  'EATON',
#  'SwaddleMe',
#  'Yamaha',
#  'Fisher-Price',
#  'Fender',
#  'Remo',
#  'ELECTRONICS',
#  'Huggies',
#  'Nuby',
#  'XGATML',
#  'EROX CORP.',
#  'Fender',
#  'XGATML',
#  'P&G',
#  'Pampers',
#  'Remo',
#  'YTC Summit',
#  'PreSonus',
#  'decalmile',
#  'EPtech',
#  'Xiamen Visual Beauty',
#  'JIM DUNLOP',
#  'Dream On Me',
#  'Pampers',
#  'Dean',
#  'Aomeiwer',
#  'DECKSAVER',
#  'Nuby',
#  'Sablanc',
#  'Peg Pergo',
#  "Dr. Brown's",
#  'DECKSAVER',
#  'LOP',
#  'Ibanez',
#  'Casio',
#  'The Holster Store',
#  "Dr. Brown's",
#  'SwaddleDesigns',
#  'Disney',
#  'BRITAX',
#  'Kala',
#  'Generic',
#  'Dr. Browns',
#  'OMNIHIL',
#  'PHILIPS SPEECH PROCESSING',
#  'XGATML',
#  'CHAUVET DJ',
#  'Medela',
#  'OUTLOOK GROUP CORP',
#  'PHILIPS SPEECH PROCESSING',
#  "Carter's",
#  'DECKSAVER',
#  'Ma Claren',
#  'PEESTE',
#  'DEMDACO - Home',
#  'Gibson',
#  'Thirsties',
#  'Thirsties',
#  'Thirsties',
#  'Medela',
#  'The Allen Company',
#  'Halson',
#  'Huggies',
#  'UPPABBY',
#  'Pampers',
#  'Thirsties',
#  'GroVia',
#  'American Baby Company',
#  'UPPAbaby',
#  'Hohner Efforl',
#  'Yamaha',
#  'JIM DUNLOP',
#  'Hohner',
#  'EPtech',
#  'Woombie',
#  'KOL',
#  'JOYO',
#  'Fender',
#  'Fender',
#  'UPPABBY',
#  'Jackson',
#  'BRITAX',
#  'DEMDACO - Home',
#  'Fender',
#  'Stokke',
#  'Pampers',
#  'Lp',
#  'CHAUVET DJ',
#  "Carter's",
#  'Ibanez',
#  'CHAUVET DJ',
#  'Stupell Industries',
#  'AMERICAN PERCUSsion',
#  'Wallmonkeys',
#  'Fender',
#  'The Allen Company',
#  'Fisher-Price',
#  'Jojo Designs, LLC',
#  'Jackson',
#  'SwaddleMe',
#  'Gibson',
#  'The Regatta Group DBA Beauty Depot',
#  'BRITAX',
#  'Audio-Technica',
#  'SAMSUNG HOUSE',
#  'Graco',
#  'BRITAX',
#  'AMS-Focusrite',
#  'JIM DUNLOP',
#  'XGATML',
#  'Caramel',
#  'Baby Fanatic',
#  'Hohner',
#  'EATON',
#  'Toca',
#  'OUTLOOK GROUP CORP',
#  'Kala',
#  'Silver Pearl',
#  'Kala',
#  'Yamaha',
#  'PHILIPS SPEECH PROCESSING',
#  'BRITAX',
#  'Huggies',
#  'EPtech',
#  'Thirsties',
#  'Pampers',
#  'Fender',
#  'Pampers',
#  'Fender',
#  'Fender',
#  'Thirsties',
#  'York Wallcoverings',
#  'Fender',
#  'Stork Craft',
#  'UPPABBY',
#  'Fender',
#  'Fender',
#  'GIBRALTAR',
#  'SwaddleDesigns',
#  'Ibanez',
#  "Dr. Brown's",
#  'KOMQI',
#  'ENERGYSOUND',
#  'Jojo Designs, LLC',
#  'Schwalbe',
#  'EATON',
#  'The First Success',
#  'Inktastic',
#  'Yamaha',
#  'SAMSUNG ELECTRONICS CO.,LTD',
#  'Everflo',
#  'Storkcraft',
#  'JIM DUNLOP',
#  'Ibanez',
#  'Lanicai',
#  'DRENGTH',
#  'BIBS',
#  'Sabri',
#  'EATON',
#  'Nuby',
#  'LOP',
#  'Hohner',
#  'Woombie',
#  'Inktastic',
#  'Sabri',
#  'Storkcraft',
#  'OnSease',
#  'Fender',
#  'EATON',
#  'Dean',
#  'Dream On Me',
#  'Silver Pearl',
#  'Caramel',
#  'Ibanez',
#  'EATON',
#  'CHDENUO',
#  'Dean',
#  'Moon',
#  'Fender',
#  'Fender',
#  'Odyssey',
#  'Ma Claren',
#  "Dr. Brown's",
#  'Inktastic',
#  'Blackstar',
#  'Stupell Industries',
#  'UPPABBY',
#  'Jackson',
#  'DECOWALL',
#  'B.C. Rich',
#  'Hohner',
#  'JIM Dunlop',
#  'XGATML',
#  'Fender',
#  'XGATML',
#  'PRS',
#  'GRACO',
#  'BRITAX',
#  'Delta',
#  "Johnson's Baby",
#  'Ibanez',
#  'EROX CORP.',
#  'OUTLOOK GROUP CORP',
#  'Jojo Designs, LLC',
#  'Silver Pearl',
#  'Inktastic',
#  'Fender',
#  'KERSTUFFUS',
#  'EATON',
#  'The First Success',
#  'Hohner',
#  'Delta',
#  'Pampers',
#  'Ma Claren',
#  'MIDI',
#  'YAFA',
#  'EATON',
#  'Blackstar',
#  'The Regatta Group DBA Beauty Depot',
#  'Gibson',
#  'Aomeiwerarabcc',
#  'NUK',
#  'EATON',
#  'XGATML',
#  'Seymour',
#  'Gibson',
#  'Aden + Anais',
#  'York Wallcoverings',
#  'Graco',
#  'MARTIN',
#  'YTC Summit',
#  'Stupell Industries',
#  'Baby Jog',
#  'Generic',
#  'Lanikai',
#  'Fender',
#  'CHAUVET DJ',
#  'Stokke',
#  'Graco',
#  'PRS',
#  'The Allen Company',
#  'decalmile',
#  'The HOLDINGS Company',
#  'Dean',
#  'Yamaha',
#  'Jojo Designs, LLC',
#  'Audio-Technica',
#  'GRACO',
#  'Audio Technica',
#  'Seymour Duncan',
#  'Fender',
#  'HQRP',
#  'Fender',
#  'Silver Pearl',
#  'EATON',
#  'Thirsties',
#  'Graco',
#  'Tommee',
#  'Fender',
#  'Kala',
#  'Jojo Designs, LLC',
#  'Gibson',
#  'Graco',
#  'PickBirl',
#  'SAMSUNG HOUSE',
#  'AIR FLOOR',
#  'GroVia',
#  'Ibanez',
#  'Thirsties',
#  'Aden + Anais',
#  'Fender',
#  'Trend Lab',
#  'The HOLDINGS Company',
#  'Aomeiwer',
#  'Huggies',
#  'Graco',
#  'Fender',
#  'Odyssey',
#  'BRITAX',
#  'Inktastic',
#  'CHAUVET DJ',
#  'Ibanez',
#  'EATON',
#  'OnSease',
#  'American Baby Company',
#  'LOP',
#  'JIM Dunlop',
#  'JIM Dunlop',
#  'Huggies',
#  'Fender',
#  'KOL',
#  'Gibson',
#  'Huggies',
#  'Yamaha',
#  'Jojo Designs, LLC',
#  'Big Rock',
#  'The Regatta Group DBA Beauty Depot',
#  'Saber',
#  'Sphinx Oriental Percussion',
#  'UBs',
#  'Graco',
#  'Nuby',
#  'Storkcraft',
#  'Huggies',
#  'Stupell Industries',
#  'Fender',
#  'Ibanez',
#  'Woombie',
#  'Baby Fanatic',
#  'Fender',
#  'Hohner Accordions',
#  'Pampers',
#  'Fender',
#  'BRITAX',
#  'AIR VALUE SELECT',
#  'Graco',
#  'SHEETWORLD.COM',
#  'Inktastic',
#  'HISCO',
#  'Ibanez',
#  'Jojo Designs, LLC',
#  'Caramel',
#  'Fender',
#  'Dream On Me',
#  'JIM Dunlop',
#  'Nuby',
#  'Prins',
#  'AomeoCraft',
#  'Fender',
#  'OnSease',
#  'decalmile',
#  "Johnson's Baby",
#  'BRITAX',
#  'Thirsties',
#  'The First Success',
#  "Dr. Brown's",
#  'Inktastic',
#  'Woombie',
#  'Hohner',
#  'Ibanez',
#  'MyVolts',
#  'LOP',
#  'EATON',
#  'Fender',
#  'The HONEST COMPANY',
#  'Delta',
#  'CREATIVE TECHNOLOGY',
#  'Hohner',
#  'Fender',
#  'Dean',
#  'Fender',
#  'Toca',
#  'Aomeiweraabbcc',
#  'DECOWALL',
#  'Fender',
#  'Prinz',
#  'Kala',
#  "D'Andre",
#  'Aden',
#  'ELECTRONICS',
#  'Audio-Technica',
#  'Fender',
#  'Fender',
#  'DECOWALL',
#  'DRCLOSE',
#  'Dean',
#  'Hohner',
#  'Silver Pearl',
#  'Pampers',
#  'Hohner',
#  'Kala',
#  'Dean',
#  'Ibanez',
#  'Stupell Industries',
#  'BIBS',
#  'SwaddleDesigns',
#  'Silver Pearl',
#  'Dean',
#  'EATON',
#  'Ibanez',
#  'Jackson',
#  'Jojo Designs, LLC',
#  'Jojo Designs, LLC',
#  'The Allen Company',
#  'Graphics and More',
#  "Dr. Brown's",
#  'SwaddleDesigns',
#  'Disney',
#  'EPtech',
#  'LOP',
#  'CHAUVET',
#  'Aden + Anais',
#  'Ibanez',
#  'Silver Pearl',
#  'Seymour',
#  'Presonus',
#  'Toca',
#  'Sabri',
#  'XGATML',
#  'Nuby',
#  'Britax',
#  'Moviegoods',
#  'Huggies',
#  'Yamaha',
#  'XGATML',
#  'Silver Pearl',
#  'SHEETWORLD.COM',
#  'SwaddleDesigns',
#  'Delta',
#  'Jojo Designs, LLC',
#  'DR STRENGTH',
#  'Nuby',
#  'EATON',
#  'The HOLDINGS LLC',
#  'Remo',
#  'Jojo Designs, LLC',
#  'Hohner',
#  'Woombie',
#  'TYG',
#  'Yamaha',
#  'P&G',
#  'ELECTRONICS CO',
#  'The HOLDINGS LLC',
#  'Moon',
#  'EATON',
#  'Peg Pergo',
#  'Gibson',
#  'SCHURTER',
#  'The HOLDINGS Company',
#  'GIBRALTAR',
#  'Yamaha',
#  'Huggies',
#  'PRS',
#  'The HOLDINGS Company',
#  'Hohner Effions',
#  'Delta',
#  "Dr. Brown's",
#  'Fender',
#  'DECOWALL',
#  'BRITAX',
#  'Wallmonkeys',
#  'Aomeiwer',
#  'XGATML',
#  'Gibson',
#  'Fender',
#  'Stork Craft',
#  'Woombie',
#  'JIM Dunlop',
#  'Schwalbe',
#  'CHAUVET',
#  'Graco',
#  "Dr. Brown's",
#  'CHAUVET DJ',
#  'DECKSAVER',
#  'Ibanez',
#  'Blackstar',
#  'ALVA',
#  'Jackson',
#  'Delta',
#  'Odyssey',
#  'NUK',
#  'Fender',
#  'Fender',
#  'Jojo Designs, LLC',
#  'Pampers',
#  'Fender',
#  'Huggies',
#  'York Wallcoverings',
#  'EROX CORP.',
#  'Lifetime Brands',
#  'The Regatta Group DBA Beauty Depot',
#  'EATON',
#  'Hohner',
#  'Generic',
#  'Fender',
#  'Hohner',
#  'Ibanez',
#  'Fender',
#  'OUTLOOK GROUP CORP',
#  'HQRP',
#  'NUK',
#  'LOP',
#  'Dean',
#  'Carters',
#  'Fender',
#  'MARTIN',
#  'Gibson',
#  'Pampers',
#  'Fender',
#  'Graphics and More',
#  'Fisher-Price',
#  'Graco',
#  'HQRP',
#  'DR STRENGTH',
#  'EATON',
#  'Delta',
#  'GIBRALTAR',
#  'SCHACTER',
#  'NUK',
#  "Carter's",
#  'Caramel',
#  'YAFA',
#  'PHILIPS SPEECH PROCESSING',
#  'decalmile',
#  'Kala',
#  'Delta',
#  'Gibson',
#  'Hohner',
#  'Oimage',
#  'Huggies',
#  'Ibanez',
#  'JIM DUNLOP',
#  'Fender',
#  'Fender',
#  "Carter's",
#  'Fender',
#  'HOHNER',
#  'Fisher-Price',
#  'HOHLER',
#  'DECKSAVER',
#  'The Allen Company',
#  'Fender',
#  'PHILIPS SPEECH PROCESSING',
#  'Graco',
#  "Dr. Brown's",
#  'PHILIPS SPEECH PROCESSING',
#  'Jojo Designs, LLC',
#  'Sabri',
#  'Woombie',
#  'GRACO',
#  'ADJ Products',
#  'Silver Pearl',
#  'Hohner',
#  'XGATML',
#  'Jojo Designs, LLC',
#  'Ma Claren',
#  'SHENZHEN TENGSHUN POWER SUPPLY CO LTD',
#  'OnSease',
#  'Huggies',
#  'EATON',
#  'EPtech',
#  'SwaddleMe',
#  'Fender',
#  'CHAUVET DJ',
#  'Aomeiwerarabcc',
#  'The HOLDINGS Company',
#  'The HOLDINGS LLC',
#  'Britax',
#  'Gold Tone',
#  'PickBirl',
#  'decalmile',
#  'JIM DUNLOP',
#  'UPPABBY',
#  'Sabar',
#  'DECOWALL',
#  'Aomeiwerarabcc',
#  'EATON',
#  'DECKSAVER',
#  'Gibson',
#  'American Baby Company',
#  'MIDI',
#  'Dean',
#  'XGATML',
#  'Pampers',
#  'EATON',
#  'Dream On Me',
#  'Fender',
#  'Gold Tone',
#  'Huggies',
#  'Remo',
#  'Jojo Designs, LLC',
#  'Seymour Duncan',
#  "D'Andre",
#  'MARTIN',
#  'Fender',
#  'JIM DUNLOP',
#  'Hohner',
#  'Britax Boulevard',
#  'PIEGEE',
#  'Kala',
#  'Fender',
#  'American Baby Company',
#  'ALVA',
#  'Jojo Designs, LLC',
#  'Graco',
#  'SHEETWORLD.COM',
#  'Fender',
#  'PACESET',
#  'The HOLDINGS Company',
#  'Peg-Pergo',
#  'The Scotts Company LLC',
#  'ELECTRONICS',
#  'Nuby',
#  'Aden',
#  'York Wallcoverings',
#  'YAFA',
#  'BIBS',
#  "Carter's",
#  'Baby Jog',
#  'Britax',
#  'Huggies',
#  'Dream On Me',
#  'B.C. Rich',
#  'Jojo Designs, LLC',
#  'Fender',
#  'aden',
#  'Jojo Designs, LLC',
#  'Jojo Designs, LLC',
#  'Kala',
#  'JIM Dunlop',
#  'YAFA',
#  'Stokke',
#  'LOP',
#  'Fender',
#  'EATON',
#  'Jojo Designs, LLC',
#  'Ibanez',
#  'Nuby',
#  'KOMQI',
#  'Huggies',
#  'Medela',
#  'Gibson',
#  'Fender',
#  'Fender',
#  'GRAPHICS & MORE',
#  'Jojo Designs, LLC',
#  'Ibanez',
#  'HQRP',
#  'Moon',
#  'Sabar',
#  'Big Rock',
#  'Baby Joetter',
#  'Big Rock',
#  'LP912',
#  'LAWN SKY',
#  'SHEETWORLD.COM',
#  'Stupell Industries',
#  'Ibanez',
#  'ELECTRONICS INC',
#  'ELECTRONICS',
#  'XGATML',
#  'OMG SPORTS',
#  'Pampers',
#  'Fender',
#  'EATON',
#  'JIM Dunlop',
#  'decalmile',
#  'JIM DUNLOP',
#  "Johnson's Baby",
#  'ALVA',
#  'PreSonus',
#  'Yamaha',
#  'OMNIHIL',
#  'Britax',
#  'Jackson',
#  'ELECTRONICS CO',
#  'Kala',
#  'PickBirl',
#  'SAMSUNG',
#  'Toca',
#  'SHENZHEN TENGSHUN POWER SUPPLY CO LTD',
#  'K-MuskuloAire',
#  'YAFA',
#  'Pampers',
#  'Kala',
#  'ENERGYSOUND',
#  'Nuby',
#  'Jackson',
#  'Wallmonkeys',
#  'Seymour Duncan',
#  'Graco',
#  'Thirsties',
#  'Blackstar',
#  'Tamiamine',
#  'DECKSAVER',
#  'Fender',
#  'DR FILTERS',
#  'Nuby',
#  'Fender',
#  'Ibanez',
#  'JIM DUNLOP',
#  'decalmile',
#  'PickBirl',
#  'SAMSUNG',
#  'Ma Claren',
#  'Stokke',
#  'KOL',
#  'Stupell Industries',
#  'Jojo Designs, LLC',
#  'Huggies',
#  'DR CLARK',
#  'Inktastic',
#  'EATON',
#  'JIM Dunlop',
#  'Sabar',
#  'Lanikai',
#  'HohnerPro',
#  'The HOLDINGS Company',
#  'B.C. Rich',
#  'GIBRALTAR',
#  'Graco',
#  'Dean',
#  'UBs',
#  'Kala',
#  'EATON',
#  'KOL',
#  "Johnson's Baby",
#  'Jojo Designs, LLC',
#  'GIBRALTAR',
#  'Jackson',
#  'Fender',
#  'Nuby',
#  'York Wallcoverings',
#  'Graco',
#  'PHILIPS SPEECH PROCESSING',
#  'Toca',
#  'Kala',
#  'SCHACTER',
#  'Jojo Designs, LLC',
#  'The HONEST CORPORATION',
#  'Schwalbe',
#  'Nuby',
#  'The Regatta Group DBA Beauty Depot',
#  'Ibanez',
#  'Trend Lab',
#  'NUK',
#  'Jojo Designs, LLC',
#  'SCHACTER',
#  'Nuby',
#  'The Allen Company',
#  'The First Ideas',
#  'American Baby Company',
#  'Dean Gibson',
#  'Nuby',
#  'Aden',
#  'Oimage',
#  'Pirasty',
#  'Ibanez',
#  'Tommee',
#  'Gibson',
#  'Hohner',
#  'Jojo Designs, LLC',
#  'Casio',
#  'Jackson',
#  'Britax Boulevard',
#  'Fender',
#  'Stokke',
#  'KOL',
#  'HQRP',
#  'Vic Firth',
#  'Huggies',
#  'Aomeiwer',
#  'American Baby Company',
#  'Yamaha',
#  'Nuby',
#  'HHC',
#  'Medela',
#  'Fender',
#  'Jojo Designs, LLC',
#  'Inktastic',
#  'Baby Joard',
#  'Tommee',
#  'YAFA',
#  'Pirasty',
#  'Sabar',
#  'Odyssey',
#  'Proctor',
#  'Huggies',
#  'Yamaha',
#  'Fender',
#  'HQRP',
#  'Yamaha',
#  'JIM Dunlop',
#  'Baby Fanatic',
#  'Dream On Me',
#  "Dr. Brown's",
#  'Fisher-Price',
#  'EROX CORP.',
#  'EATON',
#  'LP266B',
#  'DR STRENGTH',
#  'Fender',
#  'Inktastic',
#  'YORK WALLER',
#  'Pampers',
#  'BRITAX',
#  'The Allen Company',
#  'Fender',
#  'Wallmonkeys',
#  'Dean',
#  'Pampers',
#  'Trend Lab',
#  'Delta',
#  'DECOWALL',
#  'Jackson',
#  'Baby Fanatic',
#  "Johnson's Baby",
#  'CHAUVET DJ',
#  'SwaddleMe',
#  'Gibson',
#  'Fender',
#  'DR Gibson',
#  'Huggies',
#  'PHILIPS SPEECH PROCESSING',
#  "Dr. Brown's",
#  'Kala',
#  'Dean Gibson',
#  'Pampers',
#  'JIM DUNLOP',
#  'DEMDACO - Home',
#  'decalmile',
#  'SwaddleMe',
#  'EROCK CORP.',
#  'Jackson',
#  'OMNIHIL',
#  'Sixth Generation',
#  'Seymour Duncan',
#  'OnSease',
#  'Casio',
#  'The HONEST CORPORATION',
#  'UPPABBY',
#  'Yamaha',
#  'EATON',
#  'Groven',
#  'EPtech',
#  'Jojo Designs, LLC',
#  'Pampers',
#  'UBs',
#  'SHENZHEN TENGSHUN POWER SUPPLY CO LTD',
#  'PickBirl',
#  'Lifetime Brands',
#  'Ibanez',
#  'Caramel',
#  'Stokke',
#  'Hohner',
#  'Remo',
#  'Ma Claren',
#  'OUTLOOK GROUP CORP',
#  'Fender',
#  'XGATML',
#  'Delta',
#  'Remo',
#  "D'Andre",
#  'EROX CORP.',
#  'Fender',
#  'Peg Pergo',
#  'Saber',
#  'Jojo Designs, LLC',
#  'Prins',
#  'Hohner',
#  'Huggies',
#  'Tommee',
#  'Silver Pearl',
#  'Britax',
#  'EATON',
#  "Carter's",
#  'Odyssey',
#  'MyVolts',
#  'Nuby',
#  'Fender',
#  'EATON',
#  'Fender',
#  'Medela',
#  'EL',
#  'Kala',
#  'Carters',
#  'OUTLOOK GROUP CORP',
#  'Baby Joard',
#  'JIM Dunlop',
#  'JIM Dunlop',
#  'Moviegoods Mania',
#  'Pirasty',
#  'PACESET',
#  'Dream On Me',
#  'Lanikai',
#  'Ibanez',
#  'Jojo Designs, LLC',
#  'Nuby',
#  'Nuby',
#  'P&G',
#  'JOYO',
#  'Mapellen',
#  'Seymour',
#  'PerfumeWorldWide, Inc. Drop Ship',
#  'BRITAX',
#  'Gibson',
#  'Odyssey',
#  'SAMSUNG',
#  'Tommee',
#  'HQRP',
#  'The Regatta Group DBA Beauty Depot',
#  'Jojo Designs, LLC',
#  'Nuby',
#  'Ibanez',
#  'Huggies',
#  'GRACO',
#  'Graco',
#  'ELECTRONICS',
#  'UPPABBY',
#  'SHENZHEN TENGSHUN POWER SUPPLY CO LTD',
#  'Pampers',
#  'Kala',
#  'HI-Tech',
#  'CASIO',
#  'Philips',
#  'Gibson',
#  'OnSease',
#  'Fender',
#  'HaLO',
#  'Peg-Pergo',
#  'Hohner',
#  'Ibanez',
#  'LOP',
#  'Dream On Me',
#  'DR STRENGTH',
#  'CHAUVET DJ',
#  'UPPABBY',
#  'PACESET',
#  "Carter's",
#  ...]
